# %% [markdown]
# # Bibliotecas

# %%
# Bibliotecas
import bib
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
import seaborn as sns
import matplotlib.font_manager as fm
from matplotlib.ticker import FuncFormatter

# %% [markdown]
# # Base de dados

# %%
# Seed
seed = np.random.seed(45242)

# %% [markdown]
# ## Simulação das idades

# %% [markdown]
# ### Idades - Equilibrada

# %%
# Númedo de segurados
num_segurados = 100000

# Proporções para cada faixa etária
proporcoes_masc_equilibrada = {"18-25": 0.0033, "26-30": 0.0359, "31-35": 0.2091, "36-40": 0.18, "41-45": 0.215, "46-50": 0.185,
                                "51-55": 0.0824, "56-60": 0.06, "61-65": 0.005, "66-70": 0.005, "71-75": 0.005, "76-80": 0.005, 
                                "81-85": 0.0045, "86-90": 0.0045, "91-95": 0.00015, "96-100": 0.00015
}
proporcoes_fem_equilibrada = {"18-25": 0.001, "26-30": 0.0193, "31-35": 0.323, "36-40": 0.2104, "41-45": 0.204, "46-50": 0.2307,
                                "51-55": 0.057, "56-60": 0.0707, "61-65": 0.005, "66-70": 0.005, "71-75": 0.005, "76-80": 0.005, 
                                "81-85": 0.003, "86-90": 0.003, "91-95": 0.0002, "96-100": 0.0002
}

# Gerar idades para homens e mulheresidades_masc_equilibrada = bib.Bases.gerar_idades(proporcoes_masc_equilibrada, num_segurados)
idades_masc_equilibrada = bib.Bases.gerar_idades(proporcoes_masc_equilibrada, num_segurados)
idades_fem_equilibrada = bib.Bases.gerar_idades(proporcoes_fem_equilibrada, num_segurados)

# Criar DataFrames
df_masc_equilibrada = pd.DataFrame({"Idade": idades_masc_equilibrada, "Gênero": "Masculino"})
df_fem_equilibrada = pd.DataFrame({"Idade": idades_fem_equilibrada, "Gênero": "Feminino"})

# Juntar os DataFrames
df_idades_equilibrada = pd.concat([df_masc_equilibrada, df_fem_equilibrada], axis=0).reset_index(drop=True)

# %% [markdown]
# ### Idades - Bimondal

# %%
# Númedo de segurados
num_segurados = 100000

# Proporções para cada faixa etária
proporcoes_masc_bimodal = {"18-25": 0.15, "26-30": 0.10, "31-35": 0.05, "36-40": 0.03, "41-45": 0.02, "46-50": 0.04, 
                        "51-55": 0.09, "56-60": 0.06, "61-65": 0.11, "66-70": 0.2, "71-75": 0.09, "76-80": 0.05, 
                        "81-85": 0.05, "86-90": 0.03, "91-95": 0.005, "96-100": 0.005}
proporcoes_fem_bimodal = {"18-25": 0.13, "26-30": 0.12, "31-35": 0.025, "36-40": 0.025, "41-45": 0.035, "46-50": 0.025, 
                        "51-55": 0.08, "56-60": 0.1, "61-65": 0.125, "66-70": 0.105, "71-75": 0.09, "76-80": 0.05, 
                        "81-85": 0.05, "86-90": 0.03, "91-95": 0.005, "96-100": 0.005}

# Gerar idades para homens e mulheres
idades_masc_bimodal = bib.Bases.gerar_idades(proporcoes_masc_bimodal, num_segurados)
idades_fem_bimodal = bib.Bases.gerar_idades(proporcoes_fem_bimodal, num_segurados)

# Criar DataFrames
df_masc_bimodal = pd.DataFrame({'Idade': idades_masc_bimodal, 'Gênero': 'Masculino'})
df_fem_bimodal = pd.DataFrame({'Idade': idades_fem_bimodal, 'Gênero': 'Feminino'})

# Juntar os DataFrames
df_idades_bimodal = pd.concat([df_masc_bimodal, df_fem_bimodal], axis=0).reset_index(drop=True)

# %% [markdown]
# ### Idades - Jovem

# %%
# Númedo de segurados
num_segurados = 100000

# Proporções para cada faixa etária
proporcoes_masc_jovem = {"18-25": 0.25, "26-30": 0.35, "31-35": 0.15, "36-40": 0.10, "41-45": 0.04,
                        "46-50": 0.02, "51-55": 0.02, "56-60": 0.01, "61-65": 0.013, "66-70": 0.007,
                        "71-75": 0.006, "76-80": 0.004, "81-85": 0.013, "86-90": 0.007, "91-95": 0.007, "96-100": 0.003}
proporcoes_fem_jovem = {"18-25": 0.22, "26-30": 0.36, "31-35": 0.14, "36-40": 0.09, "41-45": 0.05, 
                        "46-50": 0.03, "51-55": 0.032, "56-60": 0.018, "61-65": 0.006, "66-70": 0.004, 
                        "71-75": 0.012, "76-80": 0.008, "81-85": 0.013, "86-90": 0.007, "91-95": 0.006, "96-100": 0.004}

# Gerar idades para homens e mulheres
idades_masc_jovem = bib.Bases.gerar_idades(proporcoes_masc_jovem, num_segurados)
idades_fem_jovem = bib.Bases.gerar_idades(proporcoes_fem_jovem, num_segurados)

# Criar DataFrames
df_masc_jovem = pd.DataFrame({'Idade': idades_masc_jovem, 'Gênero': 'Masculino'})
df_fem_jovem = pd.DataFrame({'Idade': idades_fem_jovem, 'Gênero': 'Feminino'})

# Juntar os DataFrames
df_idades_jovem = pd.concat([df_masc_jovem, df_fem_jovem], axis=0).reset_index(drop=True)

# %% [markdown]
# ### Idades - Idosa

# %%
# Númedo de segurados
num_segurados = 100000

# Proporções para cada faixa etária
proporcoes_masc_idosa = {"18-25": 0.02, "26-30": 0.04, "31-35": 0.018, "36-40": 0.012, "41-45": 0.055, 
                        "46-50": 0.035, "51-55": 0.130, "56-60": 0.080, "61-65":0.105, "66-70": 0.065,
                        "71-75": 0.135, "76-80": 0.085, "81-85": 0.075, "86-90": 0.045, "91-95": 0.065, "96-100": 0.035}
proporcoes_fem_idosa = {"18-25": 0.02, "26-30": 0.05, "31-35": 0.018, "36-40": 0.012, "41-45": 0.050, 
                        "46-50": 0.030, "51-55": 0.137, "56-60": 0.083, "61-65": 0.112, "66-70": 0.068, 
                        "71-75": 0.128, "76-80": 0.082, "81-85": 0.062, "86-90": 0.038, "91-95": 0.071, "96-100": 0.039}

# Gerar idades para homens e mulheres
idades_masc_idosa = bib.Bases.gerar_idades(proporcoes_masc_idosa, num_segurados)
idades_fem_idosa = bib.Bases.gerar_idades(proporcoes_fem_idosa, num_segurados)

# Criar DataFrames
df_masc_idosa = pd.DataFrame({'Idade': idades_masc_idosa, 'Gênero': 'Masculino'})
df_fem_idosa = pd.DataFrame({'Idade': idades_fem_idosa, 'Gênero': 'Feminino'})

# Juntar os DataFrames
df_idades_idosa = pd.concat([df_masc_idosa, df_fem_idosa], axis=0).reset_index(drop=True)

# %% [markdown]
# ## Pirâmides

# %%
# Confugruação do subplot
fig, axes = plt.subplots(2, 2, figsize=(20, 16))

# Lista de tuplas com as idades simuladas e posições das pirâmides 
configs = [(df_idades_bimodal, "Bimodal", axes[1, 0]), (df_idades_equilibrada, "Equilibrada", axes[0, 1]),
    (df_idades_jovem, "Jovem", axes[0, 0]), (df_idades_idosa, "Idosa", axes[1, 1]),]

# Ordem das faixas etárias
bins_edges = [18, 26, 31, 36, 41, 46, 51, 56, 61, 66, 71, 76, 81, 86, 91, 96, 101]

# Faixas etárias
labels = ["18-25", "26-30", "31-35", "36-40", "41-45", "46-50", "51-55", "56-60", 
    "61-65", "66-70", "71-75", "76-80", "81-85", "86-90", "91-95", "96-100"]

# Loop para cada subplot
for df, titulo, ax in configs:
    
    # Cópia dos dados
    df = df.copy()
    
    # Converter idades inteiras (bins_edge) em grupos (categóricos) de faixas etárias
    df['Faixa Etária'] = pd.cut(df["Idade"], bins=bins_edges, labels=labels, right=False)

    # Agrupando as idades por genero e faixa etária
    pyramid_df = df.groupby(["Faixa Etária", "Gênero"], observed=False).size().unstack().fillna(0)

    # Lado masculino da pirâmide
    ax.barh(pyramid_df.index, -pyramid_df["Masculino"], height=1.0, color="skyblue", edgecolor="black", linewidth=0.5, hatch="oo", label="Masculino")

    # Lado feminino da pirâmide
    ax.barh(pyramid_df.index, pyramid_df["Feminino"], height=1.0, color="pink", edgecolor="black", linewidth=0.5, hatch="xx", label="Feminino")

    # Valor máximo de cada lado da pirâmide
    max_value = max( pyramid_df["Masculino"].max() + 1000, pyramid_df["Feminino"].max() + 1000)
    ax.set_xlim(-max_value, max_value)

    # Eixo central da pirâmide
    ax.axvline(0, color="black", linewidth=1)

    # Formatação do eixo x
    ax.xaxis.set_major_formatter(FuncFormatter(bib.Auxiliares.formatar_milhar_abs))
    ax.set_title(f"População {titulo}", fontsize=22, fontweight="bold")
    ax.set_xlabel("Quantidade de Segurados", fontsize=22)
    ax.set_ylabel("Faixa Etária", fontsize=22)
    ax.tick_params(axis='both', labelsize=22)

    # Legenda
    ax.legend(loc='upper right', frameon=True, framealpha=1, facecolor='white', title='Gênero', title_fontsize=22, fontsize=22)

# Ajuste do tamanho torno dos subplots
plt.tight_layout()

# Estilo
plt.style.use("bmh")

# Salver em pdf
#plt.savefig("piramides_etarias.pdf")

# Mostrar gráfico
plt.show()

# %% [markdown]
# ## Descritiva

# %%
# Agrupar os DataFrames em um dicionário
bases_simuladas = {"Jovem": df_idades_jovem,  "Equilibrada": df_idades_equilibrada, "Bimodal": df_idades_bimodal, "Idosa": df_idades_idosa}

# Criar um dicionário para armazenar os resultados
resultados_estatisticos = {}

# Iterar sobre cada base para calcular as métricas
for nome_base, df in bases_simuladas.items():

    # Vetor das idades
    idades = df["Idade"]
    
    # Somar homens <= 64 e mulheres < 62
    soma_jovens = (((df["Gênero"] == "Masculino") & (df["Idade"] <= 64)).sum() + ((df["Gênero"] == "Feminino") & (df["Idade"] < 62)).sum())
    
    # Somar homens >= 65 e mulheres >= 62
    soma_idosos = (((df["Gênero"] == "Masculino") & (df["Idade"] >= 65)).sum() + ((df["Gênero"] == "Feminino") & (df["Idade"] >= 62)).sum())
    
    # Calcular a Maturidade
    if soma_idosos > 0:
        maturidade = soma_jovens / soma_idosos
    else:
        maturidade = np.nan
    
    # Preencher as estatísticas
    resultados_estatisticos[nome_base] = {
        "Idade Média": idades.mean(),
        "Idade Mediana": idades.median(),
        "Idade Mínima": idades.min(),
        "1º Quartil (25%)": idades.quantile(0.25),
        "2º Quartil (50%)": idades.quantile(0.50),
        "3º Quartil (75%)": idades.quantile(0.75),
        "Idade Máxima": idades.max(),
        "Maturidade da Massa": maturidade
    }

# Transformar o dicionário em um DataFrame
df_resumo_estatistico = pd.DataFrame(resultados_estatisticos)

# Arredondar os valores para 2 casas decimais
df_resumo_estatistico = df_resumo_estatistico.round(2)
print(df_resumo_estatistico)
# Out:
#                       Jovem  Equilibrada  Bimodal   Idosa
# Idade Média           33.57        42.54    54.15   65.13
# Idade Mediana         29.00        42.00    59.00   65.00
# Idade Mínima          19.00        19.00    19.00   19.00
# 1º Quartil (25%)      26.00        35.00    32.00   53.00
# 2º Quartil (50%)      29.00        42.00    59.00   65.00
# 3º Quartil (75%)      36.00        48.00    70.00   78.00
# Idade Máxima         100.00       100.00   100.00  100.00
# Maturidade da Massa   17.44        41.18     1.35    0.81

# %% [markdown]
# ## Bases simuladas

# %%
# Base simulada
base_simulada_equilibrada = bib.Bases.base_cadastral(df_idades_equilibrada)
base_simulada_bimodal = bib.Bases.base_cadastral(df_idades_bimodal)
base_simulada_jovem = bib.Bases.base_cadastral(df_idades_jovem)
base_simulada_idosa = bib.Bases.base_cadastral(df_idades_idosa)

# %% [markdown]
# # Tábuas e amostragem

# %%
# Ler aquivos com as tábuas

# Local
df_tabuas_masc = pd.read_excel("../Bases/tabuas_masc.xlsx")
df_tabuas_fem = pd.read_excel("../Bases/tabuas_fem.xlsx")

# Lista com os nomes da tábuas
tabuas_masculinas = [col for col in df_tabuas_masc.columns.to_list() if col != 'Idade']
tabuas_femininas = [col for col in df_tabuas_fem.columns.to_list() if col != 'Idade']

# Amostragem
base_cadastral_equilibrada = base_simulada_equilibrada.sample(n=10000, random_state=42).reset_index(drop=True)
base_cadastral_bimodal = base_simulada_bimodal.sample(n=10000, random_state=42).reset_index(drop=True)
base_cadastral_jovem = base_simulada_jovem.sample(n=10000, random_state=42).reset_index(drop=True)
base_cadastral_idosa = base_simulada_idosa.sample(n=10000, random_state=42).reset_index(drop=True)

# %% [markdown]
# # Reservas matemáticas - base equilibrada

# %%
# Calcular idade média
idade_media_equilibrada = int(base_cadastral_equilibrada["Idade"].mean())

# %% [markdown]
# ## Masculino

# %% [markdown]
# ### IEN

# %%
# Calculando a RM e testando o Art. 36 para a base cadastral

# Filtrar a base masculina
base_masc_equilibrada = base_cadastral_equilibrada[base_cadastral_equilibrada["Gênero"] == "Masculino"]

# Separar bases para PMBaC e PMBC
base_PMBaC = base_masc_equilibrada[base_masc_equilibrada["Idade"] < 65]
base_PMBC = base_masc_equilibrada[base_masc_equilibrada["Idade"] >= 65]

# Listas locais para armazenar resultados
lista_vabf, lista_vacf, lista_ex = [], [], []
lista_PMBAC, lista_PMBC, lista_RM = [], [], []

# Loop para iterar sobre as tábuas e calcular a reserva matemática
for tabua in tabuas_masculinas:

    # Probabilidade de morte da tábua
    vetor_qx = df_tabuas_masc[tabua]

    # Calcular a tábua de vida
    tabua_de_vida = bib.Calculos.calcular_tabua(vetor_qx)

    # Calcular PMBaC
    vabf_pmbac = bib.Calculos.VABF_PMBaC(base_PMBaC, tabua_de_vida, 0.05, 0.01)
    vacf_pmbac = bib.Calculos.VACF_PMBaC_INE(base_PMBaC, tabua_de_vida, vabf_pmbac, 0.05)

    # PMBaC individual (cada ativo)
    PMBaC_individual = vabf_pmbac - vacf_pmbac

    # PMBaC total (soma de todos os ativos)
    PMBaC_total = np.sum(PMBaC_individual)

    # Calcular PMBC
    PMBC_individual = bib.Calculos.VABF_PMBC(base_PMBC, tabua_de_vida, 0.05, 0.01)

    # PMBC total (soma de todos os aposentados)
    PMBC_total = np.sum(PMBC_individual)

    # Cálculo RM TOTAL
    RM_total = PMBaC_total + PMBC_total

    # Obtém a expectativa de vida na idade média
    ex_im = tabua_de_vida.loc[idade_media_equilibrada,"ex"]

    # Adiciona os valores as suas devidas listas
    lista_vabf.append(np.sum(vabf_pmbac))
    lista_vacf.append(np.sum(vacf_pmbac))
    lista_PMBAC.append(PMBaC_total)
    lista_PMBC.append(PMBC_total)
    lista_RM.append(RM_total)
    lista_ex.append(round(ex_im, 2))

# DataFrame com os resultados
df_comp = pd.DataFrame({"Tábua": tabuas_masculinas, "VABF": lista_vabf, "VACF": lista_vacf,
                        "PMBaC": lista_PMBAC, "PMBC": lista_PMBC, "RM": lista_RM,"ex": lista_ex})

# Comparar com a primeira linha
ref_ex = df_comp.loc[0, "ex"]
ref_RM = df_comp.loc[0, "RM"]

# Verificação do Art 36
df_comp["Art36_OK"] = (df_comp["ex"] >= ref_ex) & (df_comp["RM"] < ref_RM)


# Aplica o formato monetário brasileiro
for col in ["VABF", "VACF", "PMBaC", "PMBC", "RM"]:
    df_comp[col] = df_comp[col].apply(bib.Auxiliares.formatar_brasileiro)

#df_comp
# Concatenar primeira linha com linhas que atendem Art. 36
df_resultado = pd.concat([df_comp.head(1), df_comp[df_comp["Art36_OK"] == True]]).drop_duplicates()

display(df_resultado)
# Out:
#                               Tábua           VABF           VACF  \
# 0                IBGE 2024 Extrap M  97.915.657,68  18.193.346,91
# 12  IBGE 2019 Extrap. A Agrav 18,3%  97.886.469,96  18.305.567,22
# 19             AT-2000 M Agrav. 33%  98.277.291,05  18.838.431,54
# 23                   AT-55 Suave 5%  97.257.695,16  18.713.694,78
# 25         AT-83 Basic M Suave 2,5%  98.378.873,45  19.062.844,02
# 31      BR-EMSmt-v.2021 M Agrav 24%  97.955.367,13  18.687.488,38
# 39          Prudential-50 Suav. 16%  97.310.831,98  18.626.064,31
# 40          Prudential-50 Suav. 17%  97.871.081,81  18.747.270,59
# 41          Prudential-50 Suav. 18%  98.437.200,50  18.869.769,98
# 63                  M-95 H Suave 6%  97.532.276,48  18.621.812,28
#
#             PMBaC          PMBC             RM     ex  Art36_OK
# 0   79.722.310,77  6.870.331,13  86.592.641,91  35.57     False
# 12  79.580.902,73  6.932.857,77  86.513.760,50  35.60      True
# ...

# %% [markdown]
# ### CUP

# %%
# Calculando a RM e testando o Art. 36 para a base cadastral

# Filtrar a base masculina
base_masc_equilibrada = base_cadastral_equilibrada[base_cadastral_equilibrada["Gênero"] == "Masculino"]

# Separar bases para PMBaC e PMBC
base_PMBaC = base_masc_equilibrada[base_masc_equilibrada["Idade"] < 65]
base_PMBC = base_masc_equilibrada[base_masc_equilibrada["Idade"] >= 65]

# Listas locais para armazenar resultados
lista_vabf, lista_vacf, lista_ex = [], [], []
lista_PMBAC, lista_PMBC, lista_RM = [], [], []

# Loop para iterar sobre as tábuas e calcular a reserva matemática
for tabua in tabuas_masculinas:

    # Probabilidade de morte da tábua
    vetor_qx = df_tabuas_masc[tabua]

    # Calcular a tábua de vida
    tabua_de_vida = bib.Calculos.calcular_tabua(vetor_qx)

    # Calcular PMBaC
    vabf_pmbac = bib.Calculos.VABF_PMBaC(base_PMBaC, tabua_de_vida, 0.05, 0.01)
    vacf_pmbac = bib.Calculos.VACF_PMBaC_CUP(base_PMBaC, vabf_pmbac)

    # PMBaC individual (cada ativo)
    PMBaC_individual = vabf_pmbac - vacf_pmbac

    # PMBaC total (soma de todos os ativos)
    PMBaC_total = np.sum(PMBaC_individual)

    # Calcular PMBC
    PMBC_individual = bib.Calculos.VABF_PMBC(base_PMBC, tabua_de_vida, 0.05, 0.01)

    # PMBC total (soma de todos os aposentados)
    PMBC_total = np.sum(PMBC_individual)

    # Cálculo RM TOTAL
    RM_total = PMBaC_total + PMBC_total

    # Obtém a expectativa de vida na idade média
    ex_im = tabua_de_vida.loc[idade_media_equilibrada,"ex"]

    # Adiciona os valores as suas devidas listas
    lista_vabf.append(np.sum(vabf_pmbac))
    lista_vacf.append(np.sum(vacf_pmbac))
    lista_PMBAC.append(PMBaC_total)
    lista_PMBC.append(PMBC_total)
    lista_RM.append(RM_total)
    lista_ex.append(round(ex_im, 2))

# DataFrame com os resultados
df_comp = pd.DataFrame({"Tábua": tabuas_masculinas, "VABF": lista_vabf, "VACF": lista_vacf,
                        "PMBaC": lista_PMBAC, "PMBC": lista_PMBC, "RM": lista_RM,"ex": lista_ex})

# Comparar com a primeira linha
ref_ex = df_comp.loc[0, "ex"]
ref_RM = df_comp.loc[0, "RM"]

# Verificação do Art 36
df_comp["Art36_OK"] = (df_comp["ex"] >= ref_ex) & (df_comp["RM"] < ref_RM)

# Aplica o formato monetário brasileiro
for col in ["VABF", "VACF", "PMBaC", "PMBC", "RM"]:
    df_comp[col] = df_comp[col].apply(bib.Auxiliares.formatar_brasileiro)

# Concatenar primeira linha com linhas que atendem Art. 36
df_resultado = pd.concat([df_comp.head(1), df_comp[df_comp["Art36_OK"] == True]]).drop_duplicates()

display(df_resultado)
# Out:
#                           Tábua           VABF           VACF          PMBaC  \
# 0            IBGE 2024 Extrap M  97.915.657,68  39.985.694,73  57.929.962,94
# 19         AT-2000 M Agrav. 33%  98.277.291,05  40.331.137,09  57.946.153,96
# 23               AT-55 Suave 5%  97.257.695,16  39.942.339,15  57.315.356,01
# 25     AT-83 Basic M Suave 2,5%  98.378.873,45  40.451.322,34  57.927.551,11
# 31  BR-EMSmt-v.2021 M Agrav 24%  97.955.367,13  40.181.005,12  57.774.362,02
# 39      Prudential-50 Suav. 16%  97.310.831,98  39.901.970,16  57.408.861,82
# 40      Prudential-50 Suav. 17%  97.871.081,81  40.138.409,36  57.732.672,45
# 63              M-95 H Suave 6%  97.532.276,48  40.031.121,37  57.501.155,12
#
#             PMBC             RM     ex  Art36_OK
# 0   6.870.331,13  64.800.294,08  35.57     False
# 19  6.383.481,21  64.329.635,17  35.61      True
# 23  6.580.399,12  63.895.755,13  35.67      True
# 25  6.347.617,00  64.275.168,12  35.77      True
# ...

# %% [markdown]
# ### PNI

# %%
# Calculando a RM e testando o Art. 36 para a base cadastral

# Filtrar a base masculina
base_masc_equilibrada = base_cadastral_equilibrada[base_cadastral_equilibrada["Gênero"] == "Masculino"]

# Separar bases para PMBaC e PMBC
base_PMBaC = base_masc_equilibrada[base_masc_equilibrada["Idade"] < 65]
base_PMBC = base_masc_equilibrada[base_masc_equilibrada["Idade"] >= 65]

# Listas locais para armazenar resultados
lista_vabf, lista_vacf, lista_ex = [], [], []
lista_PMBAC, lista_PMBC, lista_RM = [], [], []

# Loop para iterar sobre as tábuas e calcular a reserva matemática
for tabua in tabuas_masculinas:

    # Probabilidade de morte da tábua
    vetor_qx = df_tabuas_masc[tabua]

    # Calcular a tábua de vida
    tabua_de_vida = bib.Calculos.calcular_tabua(vetor_qx)

    # Calcular PMBaC
    vabf_pmbac = bib.Calculos.VABF_PMBaC(base_PMBaC, tabua_de_vida, 0.05, 0.01)
    vacf_pmbac = bib.Calculos.VACF_PMBaC_PNI(base_PMBaC, tabua_de_vida, vabf_pmbac, 0.05, 0.01)

    # PMBaC individual (cada ativo)
    PMBaC_individual = vabf_pmbac - vacf_pmbac

    # PMBaC total (soma de todos os ativos)
    PMBaC_total = np.sum(PMBaC_individual)

    # Calcular PMBC
    PMBC_individual = bib.Calculos.VABF_PMBC(base_PMBC, tabua_de_vida, 0.05, 0.01)

    # PMBC total (soma de todos os aposentados)
    PMBC_total = np.sum(PMBC_individual)

    # Cálculo RM TOTAL
    RM_total = PMBaC_total + PMBC_total

    # Obtém a expectativa de vida na idade média
    ex_im = tabua_de_vida.loc[idade_media_equilibrada,"ex"]

    # Adiciona os valores as suas devidas listas
    lista_vabf.append(np.sum(vabf_pmbac))
    lista_vacf.append(np.sum(vacf_pmbac))
    lista_PMBAC.append(PMBaC_total)
    lista_PMBC.append(PMBC_total)
    lista_RM.append(RM_total)
    lista_ex.append(round(ex_im, 2))

# DataFrame com os resultados
df_comp = pd.DataFrame({"Tábua": tabuas_masculinas, "VABF": lista_vabf, "VACF": lista_vacf,
                        "PMBaC": lista_PMBAC, "PMBC": lista_PMBC, "RM": lista_RM,"ex": lista_ex})

# Comparar com a primeira linha
ref_ex = df_comp.loc[0, "ex"]
ref_RM = df_comp.loc[0, "RM"]

# Verificação do Art 36
df_comp["Art36_OK"] = (df_comp["ex"] >= ref_ex) & (df_comp["RM"] < ref_RM)

# Aplica o formato monetário brasileiro
for col in ["VABF", "VACF", "PMBaC", "PMBC", "RM"]:
    df_comp[col] = df_comp[col].apply(bib.Auxiliares.formatar_brasileiro)

# Concatenar primeira linha com linhas que atendem Art. 36
df_resultado = pd.concat([df_comp.head(1), df_comp[df_comp["Art36_OK"] == True]]).drop_duplicates()

display(df_resultado)
# Out:
#                               Tábua            VABF           VACF  \
# 0                IBGE 2024 Extrap M   97.915.657,68  48.764.524,00
# 8        IBGE 2021 Extrap M Suav 1%   97.783.227,95  48.857.973,95
# 12  IBGE 2019 Extrap. A Agrav 18,3%   97.886.469,96  49.561.921,61
# 19             AT-2000 M Agrav. 33%   98.277.291,05  51.254.746,59
# 23                   AT-55 Suave 5%   97.257.695,16  51.094.917,05
# 25         AT-83 Basic M Suave 2,5%   98.378.873,45  52.030.318,67
# 30      BR-EMSmt-v.2021 M Agrav 20%  100.212.504,21  51.818.703,42
# 31      BR-EMSmt-v.2021 M Agrav 24%   97.955.367,13  50.540.659,85
# 39          Prudential-50 Suav. 16%   97.310.831,98  51.247.834,48
# 40          Prudential-50 Suav. 17%   97.871.081,81  51.557.340,69
# 41          Prudential-50 Suav. 18%   98.437.200,50  51.870.096,09
# 42          Prudential-50 Suav. 19%   99.009.299,60  52.186.161,96
# 43        Prudential-50 Suav. 19,5%   99.297.627,58  52.345.455,95
# ...

# %% [markdown]
# ## Feminino

# %% [markdown]
# ### INE

# %%
# Calculando a RM e testando o Art. 36 para a base cadastral

# Filtrar a base masculina
base_fem_equilibrada = base_cadastral_equilibrada[base_cadastral_equilibrada["Gênero"] == "Feminino"]

# Separar bases para PMBaC e PMBC
base_PMBaC = base_fem_equilibrada[base_fem_equilibrada["Idade"] < 62]
base_PMBC = base_fem_equilibrada[base_fem_equilibrada["Idade"] >= 62]

# Listas locais para armazenar resultados
lista_vabf, lista_vacf, lista_ex = [], [], []
lista_PMBAC, lista_PMBC, lista_RM = [], [], []

# Loop para iterar sobre as tábuas e calcular a reserva matemática
for tabua in tabuas_femininas:

    # Probabilidade de morte da tábua
    vetor_qx = df_tabuas_fem[tabua]
    if vetor_qx.dtype == object:
        vetor_qx = vetor_qx.str.replace(",", ".").astype(float)


    # Calcular a tábua de vida
    tabua_de_vida = bib.Calculos.calcular_tabua(vetor_qx)

    # Calcular PMBaC
    vabf_pmbac = bib.Calculos.VABF_PMBaC(base_PMBaC, tabua_de_vida, 0.05, 0.01)
    vacf_pmbac = bib.Calculos.VACF_PMBaC_INE(base_PMBaC, tabua_de_vida, vabf_pmbac, 0.05)

    # PMBaC individual (cada ativo)
    PMBaC_individual = vabf_pmbac - vacf_pmbac

    # PMBaC total (soma de todos os ativos)
    PMBaC_total = np.sum(PMBaC_individual)

    # Calcular PMBC
    PMBC_individual = bib.Calculos.VABF_PMBC(base_PMBC, tabua_de_vida, 0.05, 0.01)

    # PMBC total (soma de todos os aposentados)
    PMBC_total = np.sum(PMBC_individual)

    # Cálculo RM TOTAL
    RM_total = PMBaC_total + PMBC_total

    # Obtém a expectativa de vida na idade média
    ex_im = tabua_de_vida.loc[idade_media_equilibrada,'ex']

    # Adiciona os valores as suas devidas listas
    lista_vabf.append(np.sum(vabf_pmbac))
    lista_vacf.append(np.sum(vacf_pmbac))
    lista_PMBAC.append(PMBaC_total)
    lista_PMBC.append(PMBC_total)
    lista_RM.append(RM_total)
    lista_ex.append(round(ex_im, 2))

# DataFrame com os resultados
df_comp = pd.DataFrame({'Tábua': tabuas_femininas, 'VABF': lista_vabf, 'VACF': lista_vacf,
                        'PMBaC': lista_PMBAC, 'PMBC': lista_PMBC, 'RM': lista_RM,'ex': lista_ex})

# Comparar com a primeira linha
ref_ex = df_comp.loc[0, 'ex']
ref_RM = df_comp.loc[0, 'RM']

# Verificação do Art 36
df_comp['Art36_OK'] = (df_comp['ex'] >= ref_ex) & (df_comp['RM'] < ref_RM)

# Aplica o formato monetário brasileiro
for col in ['VABF', 'VACF', 'PMBaC', 'PMBC', 'RM']:
    df_comp[col] = df_comp[col].apply(bib.Auxiliares.formatar_brasileiro)

df_comp

# Concatenar primeira linha com linhas que atendem Art. 36
df_resultado = pd.concat([df_comp.head(1), df_comp[df_comp["Art36_OK"] == True]]).drop_duplicates()

display(df_resultado)
# Out:
#                                 Tábua            VABF           VACF  \
# 0                  IBGE 2024 F Extrap  158.768.765,24  31.025.320,60
# 10     BR-EMSmt-v.2021 F Agrav. 21,5%  158.204.144,12  31.062.163,89
# 34  IBGE 2019 Extrap. Ambos Suave 19%  156.860.166,78  30.286.568,26
# 35                IBGE 2019 Extrap. F  157.972.544,21  30.836.667,38
# 48               Petros Suavizada 15%  158.833.492,86  31.399.697,83
#
#              PMBaC          PMBC              RM     ex  Art36_OK
# 0   127.743.444,64  6.825.047,66  134.568.492,31  40.20     False
# 10  127.141.980,22  6.875.418,92  134.017.399,15  40.24      True
# 34  126.573.598,52  7.155.737,35  133.729.335,87  40.26      True
# 35  127.135.876,83  7.008.170,92  134.144.047,75  40.31      True
# 48  127.433.795,03  6.738.320,69  134.172.115,72  40.24      True

# %% [markdown]
# ### PUC

# %%
# Calculando a RM e testando o Art. 36 para a base cadastral

# Filtrar a base masculina
base_fem_equilibrada = base_cadastral_equilibrada[base_cadastral_equilibrada["Gênero"] == "Feminino"]

# Separar bases para PMBaC e PMBC
base_PMBaC = base_fem_equilibrada[base_fem_equilibrada["Idade"] < 62]
base_PMBC = base_fem_equilibrada[base_fem_equilibrada["Idade"] >= 62]

# Listas locais para armazenar resultados
lista_vabf, lista_vacf, lista_ex = [], [], []
lista_PMBAC, lista_PMBC, lista_RM = [], [], []

# Loop para iterar sobre as tábuas e calcular a reserva matemática
for tabua in tabuas_femininas:

    # Probabilidade de morte da tábua
    vetor_qx = df_tabuas_fem[tabua]
    if vetor_qx.dtype == object:
        vetor_qx = vetor_qx.str.replace(",", ".").astype(float)

    # Calcular a tábua de vida
    tabua_de_vida = bib.Calculos.calcular_tabua(vetor_qx)

    # Calcular PMBaC
    vabf_pmbac = bib.Calculos.VABF_PMBaC(base_PMBaC, tabua_de_vida, 0.05, 0.01)
    vacf_pmbac = bib.Calculos.VACF_PMBaC_CUP(base_PMBaC, vabf_pmbac)

    # PMBaC individual (cada ativo)
    PMBaC_individual = vabf_pmbac - vacf_pmbac

    # PMBaC total (soma de todos os ativos)
    PMBaC_total = np.sum(PMBaC_individual)

    # Calcular PMBC
    PMBC_individual = bib.Calculos.VABF_PMBC(base_PMBC, tabua_de_vida, 0.05, 0.01)

    # PMBC total (soma de todos os aposentados)
    PMBC_total = np.sum(PMBC_individual)

    # Cálculo RM TOTAL
    RM_total = PMBaC_total + PMBC_total

    # Obtém a expectativa de vida na idade média
    ex_im = tabua_de_vida.loc[idade_media_equilibrada,"ex"]

    # Adiciona os valores as suas devidas listas
    lista_vabf.append(np.sum(vabf_pmbac))
    lista_vacf.append(np.sum(vacf_pmbac))
    lista_PMBAC.append(PMBaC_total)
    lista_PMBC.append(PMBC_total)
    lista_RM.append(RM_total)
    lista_ex.append(round(ex_im, 2))

# DataFrame com os resultados
df_comp = pd.DataFrame({"Tábua": tabuas_femininas, "VABF": lista_vabf, "VACF": lista_vacf,
                        "PMBaC": lista_PMBAC, "PMBC": lista_PMBC, "RM": lista_RM,"ex": lista_ex})

# Comparar com a primeira linha
ref_ex = df_comp.loc[0, "ex"]
ref_RM = df_comp.loc[0, "RM"]

# Verificação do Art 36
df_comp["Art36_OK"] = (df_comp["ex"] >= ref_ex) & (df_comp["RM"] < ref_RM)

# Aplica o formato monetário brasileiro
for col in ["VABF", "VACF", "PMBaC", "PMBC", "RM"]:
    df_comp[col] = df_comp[col].apply(bib.Auxiliares.formatar_brasileiro)

# Concatenar primeira linha com linhas que atendem Art. 36
df_resultado = pd.concat([df_comp.head(1), df_comp[df_comp["Art36_OK"] == True]]).drop_duplicates()

display(df_resultado)
# Out:
#                                 Tábua            VABF           VACF  \
# 0                  IBGE 2024 F Extrap  158.768.765,24  62.188.664,49
# 10     BR-EMSmt-v.2021 F Agrav. 21,5%  158.204.144,12  62.029.324,90
# 34  IBGE 2019 Extrap. Ambos Suave 19%  156.860.166,78  61.281.057,39
# 35                IBGE 2019 Extrap. F  157.972.544,21  61.844.086,08
# 48               Petros Suavizada 15%  158.833.492,86  62.371.833,67
#
#             PMBaC          PMBC              RM     ex  Art36_OK
# 0   96.580.100,75  6.825.047,66  103.405.148,42  40.20     False
# 10  96.174.819,22  6.875.418,92  103.050.238,14  40.24      True
# 34  95.579.109,39  7.155.737,35  102.734.846,74  40.26      True
# 35  96.128.458,13  7.008.170,92  103.136.629,05  40.31      True
# 48  96.461.659,18  6.738.320,69  103.199.979,88  40.24      True

# %% [markdown]
# ### PNI

# %%
# Calculando a RM e testando o Art. 36 para a base cadastral

# Filtrar a base masculina
base_fem_equilibrada = base_cadastral_equilibrada[base_cadastral_equilibrada["Gênero"] == "Feminino"]

# Separar bases para PMBaC e PMBC
base_PMBaC = base_fem_equilibrada[base_fem_equilibrada["Idade"] < 62]
base_PMBC = base_fem_equilibrada[base_fem_equilibrada["Idade"] >= 62]


# Listas locais para armazenar resultados
lista_vabf, lista_vacf, lista_ex = [], [], []
lista_PMBAC, lista_PMBC, lista_RM = [], [], []

# Loop para iterar sobre as tábuas e calcular a reserva matemática
for tabua in tabuas_femininas:

    # Probabilidade de morte da tábua
    vetor_qx = df_tabuas_fem[tabua]
    if vetor_qx.dtype == object:
        vetor_qx = vetor_qx.str.replace(",", ".").astype(float)

    # Calcular a tábua de vida
    tabua_de_vida = bib.Calculos.calcular_tabua(vetor_qx)

    # Calcular PMBaC
    vabf_pmbac = bib.Calculos.VABF_PMBaC(base_PMBaC, tabua_de_vida, 0.05, 0.01)
    vacf_pmbac = bib.Calculos.VACF_PMBaC_PNI(base_PMBaC, tabua_de_vida, vabf_pmbac, 0.05, 0.01)

    # PMBaC individual (cada ativo)
    PMBaC_individual = vabf_pmbac - vacf_pmbac

    # PMBaC total (soma de todos os ativos)
    PMBaC_total = np.sum(PMBaC_individual)

    # Calcular PMBC
    PMBC_individual = bib.Calculos.VABF_PMBC(base_PMBC, tabua_de_vida, 0.05, 0.01)

    # PMBC total (soma de todos os aposentados)
    PMBC_total = np.sum(PMBC_individual)

    # Cálculo RM TOTAL
    RM_total = PMBaC_total + PMBC_total

    # Obtém a expectativa de vida na idade média
    ex_im = tabua_de_vida.loc[idade_media_equilibrada,"ex"]

    # Adiciona os valores as suas devidas listas
    lista_vabf.append(np.sum(vabf_pmbac))
    lista_vacf.append(np.sum(vacf_pmbac))
    lista_PMBAC.append(PMBaC_total)
    lista_PMBC.append(PMBC_total)
    lista_RM.append(RM_total)
    lista_ex.append(round(ex_im, 2))

# DataFrame com os resultados
df_comp = pd.DataFrame({"Tábua": tabuas_femininas, "VABF": lista_vabf, "VACF": lista_vacf,
                        "PMBaC": lista_PMBAC, "PMBC": lista_PMBC, "RM": lista_RM,"ex": lista_ex})

# Comparar com a primeira linha
ref_ex = df_comp.loc[0, "ex"]
ref_RM = df_comp.loc[0, "RM"]

# Verificação do Art 36
df_comp["Art36_OK"] = (df_comp["ex"] >= ref_ex) & (df_comp["RM"] < ref_RM)

# Aplica o formato monetário brasileiro
for col in ["VABF", "VACF", "PMBaC", "PMBC", "RM"]:
    df_comp[col] = df_comp[col].apply(bib.Auxiliares.formatar_brasileiro)

# Concatenar primeira linha com linhas que atendem Art. 36
df_resultado = pd.concat([df_comp.head(1), df_comp[df_comp["Art36_OK"] == True]]).drop_duplicates()

display(df_resultado)
# Out:
#                              Tábua            VABF            VACF  \
# 0               IBGE 2024 F Extrap  158.768.765,24   98.393.750,77
# 10  BR-EMSmt-v.2021 F Agrav. 21,5%  158.204.144,12   98.485.945,21
# 14                GAM-71 F Suav 5%  161.742.998,74  101.527.414,07
# 20             IBGE 2020 Extrap. F  158.703.267,04   98.577.260,58
# 35             IBGE 2019 Extrap. F  157.972.544,21   98.069.338,15
# 48            Petros Suavizada 15%  158.833.492,86   99.760.290,20
# 49            Petros Suavizada 17%  159.861.998,55  100.440.685,57
#
#             PMBaC          PMBC             RM     ex  Art36_OK
# 0   60.375.014,47  6.825.047,66  67.200.062,13  40.20     False
# 10  59.718.198,91  6.875.418,92  66.593.617,83  40.24      True
# 14  60.215.584,67  6.669.567,50  66.885.152,17  40.65      True
# 20  60.126.006,46  7.043.579,91  67.169.586,38  40.48      True
# 35  59.903.206,06  7.008.170,92  66.911.376,98  40.31      True
# ...

# %% [markdown]
# # Reservas matemáticas - base bimodal

# %%
# Calcular idade média
idade_media_bimodal = int(base_cadastral_bimodal["Idade"].mean())

# %% [markdown]
# ## Masculino

# %% [markdown]
# ### IEN

# %%
# Calculando a RM e testando o Art. 36 para a base cadastral

# Filtrar a base masculina
base_masc_bimodal = base_cadastral_bimodal[base_cadastral_bimodal["Gênero"] == "Masculino"]

# Separar bases para PMBaC e PMBC
base_PMBaC = base_masc_bimodal[base_masc_bimodal["Idade"] < 65]
base_PMBC = base_masc_bimodal[base_masc_bimodal["Idade"] >= 65]

# Listas locais para armazenar resultados
lista_vabf, lista_vacf, lista_ex = [], [], []
lista_PMBAC, lista_PMBC, lista_RM = [], [], []

# Loop para iterar sobre as tábuas e calcular a reserva matemática
for tabua in tabuas_masculinas:

    # Probabilidade de morte da tábua
    vetor_qx = df_tabuas_masc[tabua]

    # Calcular a tábua de vida
    tabua_de_vida = bib.Calculos.calcular_tabua(vetor_qx)

    # Calcular PMBaC
    vabf_pmbac = bib.Calculos.VABF_PMBaC(base_PMBaC, tabua_de_vida, 0.05, 0.01)
    vacf_pmbac = bib.Calculos.VACF_PMBaC_INE(base_PMBaC, tabua_de_vida, vabf_pmbac, 0.05)

    # PMBaC individual (cada ativo)
    PMBaC_individual = vabf_pmbac - vacf_pmbac

    # PMBaC total (soma de todos os ativos)
    PMBaC_total = np.sum(PMBaC_individual)

    # Calcular PMBC
    PMBC_individual = bib.Calculos.VABF_PMBC(base_PMBC, tabua_de_vida, 0.05, 0.01)

    # PMBC total (soma de todos os aposentados)
    PMBC_total = np.sum(PMBC_individual)

    # Cálculo RM TOTAL
    RM_total = PMBaC_total + PMBC_total

    # Obtém a expectativa de vida na idade média
    ex_im = tabua_de_vida.loc[idade_media_bimodal,"ex"]

    # Adiciona os valores as suas devidas listas
    lista_vabf.append(np.sum(vabf_pmbac))
    lista_vacf.append(np.sum(vacf_pmbac))
    lista_PMBAC.append(PMBaC_total)
    lista_PMBC.append(PMBC_total)
    lista_RM.append(RM_total)
    lista_ex.append(round(ex_im, 2))

# DataFrame com os resultados
df_comp = pd.DataFrame({"Tábua": tabuas_masculinas, "VABF": lista_vabf, "VACF": lista_vacf,
                        "PMBaC": lista_PMBAC, "PMBC": lista_PMBC, "RM": lista_RM,"ex": lista_ex})

# Comparar com a primeira linha
ref_ex = df_comp.loc[0, "ex"]
ref_RM = df_comp.loc[0, "RM"]

# Verificação do Art 36
df_comp["Art36_OK"] = (df_comp["ex"] >= ref_ex) #& (df_comp["RM"] < ref_RM)

# Aplica o formato monetário brasileiro
for col in ["VABF", "VACF", "PMBaC", "PMBC", "RM"]:
    df_comp[col] = df_comp[col].apply(bib.Auxiliares.formatar_brasileiro)

# Concatenar primeira linha com linhas que atendem Art. 36
df_resultado = pd.concat([df_comp.head(1), df_comp[df_comp["Art36_OK"] == True]]).drop_duplicates()

display(df_resultado)
# Out:
#                               Tábua            VABF           VACF  \
# 0                IBGE 2024 Extrap M   78.658.551,33  11.308.026,96
# 8        IBGE 2021 Extrap M Suav 1%   78.700.006,80  11.294.866,46
# 10              IBGE 2019 Extrap. A   85.217.972,82  12.659.802,89
# 12  IBGE 2019 Extrap. A Agrav 18,3%   78.638.513,04  11.400.172,63
# 14              IBGE 2018 Extrap. A   84.733.151,12  12.560.618,88
# 17             AT-2000 (Suav 10%) M   93.274.053,37  14.544.965,88
# 18                        AT-2000 M   90.256.595,53  13.979.828,58
# 26                      AT-83 IAM M   86.604.022,62  13.258.151,67
# 27                BR-EMSmt-v.2021 M   86.547.436,58  13.223.177,60
# 28      BR-EMSmt-v.2021 M Agrav 10%   83.334.052,18  12.619.528,24
# 29      BR-EMSmt-v.2021 M Agrav 15%   81.564.447,72  12.286.966,29
# 30      BR-EMSmt-v.2021 M Agrav 20%   79.668.548,77  11.930.652,17
# 37                          GR-95 M   89.503.990,08  13.507.377,93
# ...

# %% [markdown]
# ### CUP

# %%
# Calculando a RM e testando o Art. 36 para a base cadastral

# Filtrar a base masculina
base_masc_bimodal = base_cadastral_bimodal[base_cadastral_bimodal["Gênero"] == "Masculino"]

# Separar bases para PMBaC e PMBC
base_PMBaC = base_masc_bimodal[base_masc_bimodal["Idade"] < 65]
base_PMBC = base_masc_bimodal[base_masc_bimodal["Idade"] >= 65]

# Listas locais para armazenar resultados
lista_vabf, lista_vacf, lista_ex = [], [], []
lista_PMBAC, lista_PMBC, lista_RM = [], [], []

# Loop para iterar sobre as tábuas e calcular a reserva matemática
for tabua in tabuas_masculinas:

    # Probabilidade de morte da tábua
    vetor_qx = df_tabuas_masc[tabua]

    # Calcular a tábua de vida
    tabua_de_vida = bib.Calculos.calcular_tabua(vetor_qx)

    # Calcular PMBaC
    vabf_pmbac = bib.Calculos.VABF_PMBaC(base_PMBaC, tabua_de_vida, 0.05, 0.01)
    vacf_pmbac = bib.Calculos.VACF_PMBaC_CUP(base_PMBaC, vabf_pmbac)

    # PMBaC individual (cada ativo)
    PMBaC_individual = vabf_pmbac - vacf_pmbac

    # PMBaC total (soma de todos os ativos)
    PMBaC_total = np.sum(PMBaC_individual)

    # Calcular PMBC
    PMBC_individual = bib.Calculos.VABF_PMBC(base_PMBC, tabua_de_vida, 0.05, 0.01)

    # PMBC total (soma de todos os aposentados)
    PMBC_total = np.sum(PMBC_individual)

    # Cálculo RM TOTAL
    RM_total = PMBaC_total + PMBC_total

    # Obtém a expectativa de vida na idade média
    ex_im = tabua_de_vida.loc[idade_media_bimodal,"ex"]

    # Adiciona os valores as suas devidas listas
    lista_vabf.append(np.sum(vabf_pmbac))
    lista_vacf.append(np.sum(vacf_pmbac))
    lista_PMBAC.append(PMBaC_total)
    lista_PMBC.append(PMBC_total)
    lista_RM.append(RM_total)
    lista_ex.append(round(ex_im, 2))

# DataFrame com os resultados
df_comp = pd.DataFrame({"Tábua": tabuas_masculinas, "VABF": lista_vabf, "VACF": lista_vacf,
                        "PMBaC": lista_PMBAC, "PMBC": lista_PMBC, "RM": lista_RM,"ex": lista_ex})

# Comparar com a primeira linha
ref_ex = df_comp.loc[0, "ex"]
ref_RM = df_comp.loc[0, "RM"]

# Verificação do Art 36
df_comp["Art36_OK"] = (df_comp["ex"] >= ref_ex) & (df_comp["RM"] < ref_RM)

# Aplica o formato monetário brasileiro
for col in ["VABF", "VACF", "PMBaC", "PMBC", "RM"]:
    df_comp[col] = df_comp[col].apply(bib.Auxiliares.formatar_brasileiro)

# Concatenar primeira linha com linhas que atendem Art. 36
df_resultado = pd.concat([df_comp.head(1), df_comp[df_comp["Art36_OK"] == True]]).drop_duplicates()

display(df_resultado)
# Out:
#                               Tábua           VABF           VACF  \
# 0                IBGE 2024 Extrap M  78.658.551,33  21.434.205,92
# 12  IBGE 2019 Extrap. A Agrav 18,3%  78.638.513,04  21.487.249,45
# 30      BR-EMSmt-v.2021 M Agrav 20%  79.668.548,77  22.085.914,19
#
#             PMBaC            PMBC              RM     ex  Art36_OK
# 0   57.224.345,42  121.237.725,30  178.462.070,71  25.44     False
# 12  57.151.263,59  121.278.294,66  178.429.558,25  25.45      True
# 30  57.582.634,58  118.616.135,54  176.198.770,12  25.55      True

# %% [markdown]
# ### PNI

# %%
# Calculando a RM e testando o Art. 36 para a base cadastral

# Filtrar a base masculina
base_masc_bimodal = base_cadastral_bimodal[base_cadastral_bimodal["Gênero"] == "Masculino"]

# Separar bases para PMBaC e PMBC
base_PMBaC = base_masc_bimodal[base_masc_bimodal["Idade"] < 65]
base_PMBC = base_masc_bimodal[base_masc_bimodal["Idade"] >= 65]

# Listas locais para armazenar resultados
lista_vabf, lista_vacf, lista_ex = [], [], []
lista_PMBAC, lista_PMBC, lista_RM = [], [], []

# Loop para iterar sobre as tábuas e calcular a reserva matemática
for tabua in tabuas_masculinas:

    # Probabilidade de morte da tábua
    vetor_qx = df_tabuas_masc[tabua]

    # Calcular a tábua de vida
    tabua_de_vida = bib.Calculos.calcular_tabua(vetor_qx)

    # Calcular PMBaC
    vabf_pmbac = bib.Calculos.VABF_PMBaC(base_PMBaC, tabua_de_vida, 0.05, 0.01)
    vacf_pmbac = bib.Calculos.VACF_PMBaC_PNI(base_PMBaC, tabua_de_vida, vabf_pmbac, 0.05, 0.01)

    # PMBaC individual (cada ativo)
    PMBaC_individual = vabf_pmbac - vacf_pmbac

    # PMBaC total (soma de todos os ativos)
    PMBaC_total = np.sum(PMBaC_individual)

    # Calcular PMBC
    PMBC_individual = bib.Calculos.VABF_PMBC(base_PMBC, tabua_de_vida, 0.05, 0.01)

    # PMBC total (soma de todos os aposentados)
    PMBC_total = np.sum(PMBC_individual)

    # Cálculo RM TOTAL
    RM_total = PMBaC_total + PMBC_total

    # Obtém a expectativa de vida na idade média
    ex_im = tabua_de_vida.loc[idade_media_bimodal,"ex"]

    # Adiciona os valores as suas devidas listas
    lista_vabf.append(np.sum(vabf_pmbac))
    lista_vacf.append(np.sum(vacf_pmbac))
    lista_PMBAC.append(PMBaC_total)
    lista_PMBC.append(PMBC_total)
    lista_RM.append(RM_total)
    lista_ex.append(round(ex_im, 2))

# DataFrame com os resultados
df_comp = pd.DataFrame({"Tábua": tabuas_masculinas, "VABF": lista_vabf, "VACF": lista_vacf,
                        "PMBaC": lista_PMBAC, "PMBC": lista_PMBC, "RM": lista_RM,"ex": lista_ex})

# Comparar com a primeira linha
ref_ex = df_comp.loc[0, "ex"]
ref_RM = df_comp.loc[0, "RM"]

# Verificação do Art 36
df_comp["Art36_OK"] = (df_comp["ex"] >= ref_ex) & (df_comp["RM"] < ref_RM)

# Aplica o formato monetário brasileiro
for col in ["VABF", "VACF", "PMBaC", "PMBC", "RM"]:
    df_comp[col] = df_comp[col].apply(bib.Auxiliares.formatar_brasileiro)

# Concatenar primeira linha com linhas que atendem Art. 36
df_resultado = pd.concat([df_comp.head(1), df_comp[df_comp["Art36_OK"] == True]]).drop_duplicates()

display(df_resultado)
# Out:
#                               Tábua           VABF           VACF  \
# 0                IBGE 2024 Extrap M  78.658.551,33  60.301.433,99
# 12  IBGE 2019 Extrap. A Agrav 18,3%  78.638.513,04  61.289.887,18
# 28      BR-EMSmt-v.2021 M Agrav 10%  83.334.052,18  68.135.014,51
# 29      BR-EMSmt-v.2021 M Agrav 15%  81.564.447,72  66.343.233,43
# 30      BR-EMSmt-v.2021 M Agrav 20%  79.668.548,77  64.423.570,49
# 41          Prudential-50 Suav. 18%  78.747.894,67  64.371.322,30
# 42          Prudential-50 Suav. 19%  79.157.973,51  64.776.769,90
# 43        Prudential-50 Suav. 19,5%  79.364.651,53  64.981.123,40
# 44          Prudential-50 Suav. 20%  79.572.436,26  65.186.577,11
# 46                        RP-2000 M  85.667.277,12  72.996.907,81
# 49                        UP - 94 M  82.720.291,91  69.434.008,88
# 58        BR-EMSmt 2015 M Agrav 25%  81.028.886,44  65.036.773,01
# 61                           Petros  86.941.501,55  73.640.604,91
#
# ...

# %% [markdown]
# ## Feminino

# %% [markdown]
# ### INE

# %%
# Calculando a RM e testando o Art. 36 para a base cadastral

# Filtrar a base masculina
base_fem_bimodal = base_cadastral_bimodal[base_cadastral_bimodal["Gênero"] == "Feminino"]

# Separar bases para PMBaC e PMBC
base_PMBaC = base_fem_bimodal[base_fem_bimodal["Idade"] < 62]
base_PMBC = base_fem_bimodal[base_fem_bimodal["Idade"] >= 62]


# Listas locais para armazenar resultados
lista_vabf, lista_vacf, lista_ex = [], [], []
lista_PMBAC, lista_PMBC, lista_RM = [], [], []

# Loop para iterar sobre as tábuas e calcular a reserva matemática
for tabua in tabuas_femininas:

    # Probabilidade de morte da tábua
    vetor_qx = df_tabuas_fem[tabua]
    if vetor_qx.dtype == object:
        vetor_qx = vetor_qx.str.replace(",", ".").astype(float)


    # Calcular a tábua de vida
    tabua_de_vida = bib.Calculos.calcular_tabua(vetor_qx)

    # Calcular PMBaC
    vabf_pmbac = bib.Calculos.VABF_PMBaC(base_PMBaC, tabua_de_vida, 0.05, 0.01)
    vacf_pmbac = bib.Calculos.VACF_PMBaC_INE(base_PMBaC, tabua_de_vida, vabf_pmbac, 0.05)

    # PMBaC individual (cada ativo)
    PMBaC_individual = vabf_pmbac - vacf_pmbac

    # PMBaC total (soma de todos os ativos)
    PMBaC_total = np.sum(PMBaC_individual)

    # Calcular PMBC
    PMBC_individual = bib.Calculos.VABF_PMBC(base_PMBC, tabua_de_vida, 0.05, 0.01)

    # PMBC total (soma de todos os aposentados)
    PMBC_total = np.sum(PMBC_individual)

    # Cálculo RM TOTAL
    RM_total = PMBaC_total + PMBC_total

    # Obtém a expectativa de vida na idade média
    ex_im = tabua_de_vida.loc[idade_media_bimodal,'ex']

    # Adiciona os valores as suas devidas listas
    lista_vabf.append(np.sum(vabf_pmbac))
    lista_vacf.append(np.sum(vacf_pmbac))
    lista_PMBAC.append(PMBaC_total)
    lista_PMBC.append(PMBC_total)
    lista_RM.append(RM_total)
    lista_ex.append(round(ex_im, 2))

# DataFrame com os resultados
df_comp = pd.DataFrame({'Tábua': tabuas_femininas, 'VABF': lista_vabf, 'VACF': lista_vacf,
                        'PMBaC': lista_PMBAC, 'PMBC': lista_PMBC, 'RM': lista_RM,'ex': lista_ex})

# Comparar com a primeira linha
ref_ex = df_comp.loc[0, 'ex']
ref_RM = df_comp.loc[0, 'RM']

# Verificação do Art 36
df_comp['Art36_OK'] = (df_comp['ex'] >= ref_ex) #& (df_comp['RM'] < ref_RM)

# Aplica o formato monetário brasileiro
for col in ['VABF', 'VACF', 'PMBaC', 'PMBC', 'RM']:
    df_comp[col] = df_comp[col].apply(bib.Auxiliares.formatar_brasileiro)

# Concatenar primeira linha com linhas que atendem Art. 36
df_resultado = pd.concat([df_comp.head(1), df_comp[df_comp["Art36_OK"] == True]]).drop_duplicates()

display(df_resultado)
# Out:
#                                 Tábua            VABF           VACF  \
# 0                  IBGE 2024 F Extrap   89.269.813,56  15.689.693,42
# 2                AT-2000 (Suav 10%) F   98.745.529,35  17.839.616,73
# 4                           AT-2000 F   96.673.528,02  17.415.950,34
# 7                       AT-83 Basic F   92.802.720,76  16.704.313,08
# 8                         AT-83 IAM F   96.036.426,46  17.274.868,53
# 9                   BR-EMSmt-v.2021 F   94.442.593,23  16.861.303,78
# 11                  BR-EMSsb-v.2021 F  101.023.113,34  18.249.144,46
# 14                   GAM-71 F Suav 5%   90.403.464,51  16.207.946,84
# 15                 GAM-71 F Suav 7,5%   90.979.928,63  16.325.343,69
# 16                  GAM-71 F Suav 10%   91.568.462,60  16.445.093,65
# 18                             GKF-95   93.253.447,98  16.686.703,68
# 19                            GR-95 F  105.306.401,23  18.900.168,90
# 20                IBGE 2020 Extrap. F   89.342.728,76  15.687.760,60
# ...

# %% [markdown]
# ### PUC

# %%
# Calculando a RM e testando o Art. 36 para a base cadastral

# Filtrar a base masculina
base_fem_bimodal = base_cadastral_bimodal[base_cadastral_bimodal["Gênero"] == "Feminino"]

# Separar bases para PMBaC e PMBC
base_PMBaC = base_fem_bimodal[base_fem_bimodal["Idade"] < 62]
base_PMBC = base_fem_bimodal[base_fem_bimodal["Idade"] >= 62]

# Listas locais para armazenar resultados
lista_vabf, lista_vacf, lista_ex = [], [], []
lista_PMBAC, lista_PMBC, lista_RM = [], [], []

# Loop para iterar sobre as tábuas e calcular a reserva matemática
for tabua in tabuas_femininas:

    # Probabilidade de morte da tábua
    vetor_qx = df_tabuas_fem[tabua]
    if vetor_qx.dtype == object:
        vetor_qx = vetor_qx.str.replace(",", ".").astype(float)

    # Calcular a tábua de vida
    tabua_de_vida = bib.Calculos.calcular_tabua(vetor_qx)

    # Calcular PMBaC
    vabf_pmbac = bib.Calculos.VABF_PMBaC(base_PMBaC, tabua_de_vida, 0.05, 0.01)
    vacf_pmbac = bib.Calculos.VACF_PMBaC_CUP(base_PMBaC, vabf_pmbac)

    # PMBaC individual (cada ativo)
    PMBaC_individual = vabf_pmbac - vacf_pmbac

    # PMBaC total (soma de todos os ativos)
    PMBaC_total = np.sum(PMBaC_individual)

    # Calcular PMBC
    PMBC_individual = bib.Calculos.VABF_PMBC(base_PMBC, tabua_de_vida, 0.05, 0.01)

    # PMBC total (soma de todos os aposentados)
    PMBC_total = np.sum(PMBC_individual)

    # Cálculo RM TOTAL
    RM_total = PMBaC_total + PMBC_total

    # Obtém a expectativa de vida na idade média
    ex_im = tabua_de_vida.loc[idade_media_bimodal,"ex"]

    # Adiciona os valores as suas devidas listas
    lista_vabf.append(np.sum(vabf_pmbac))
    lista_vacf.append(np.sum(vacf_pmbac))
    lista_PMBAC.append(PMBaC_total)
    lista_PMBC.append(PMBC_total)
    lista_RM.append(RM_total)
    lista_ex.append(round(ex_im, 2))

# DataFrame com os resultados
df_comp = pd.DataFrame({"Tábua": tabuas_femininas, "VABF": lista_vabf, "VACF": lista_vacf,
                        "PMBaC": lista_PMBAC, "PMBC": lista_PMBC, "RM": lista_RM,"ex": lista_ex})

# Comparar com a primeira linha
ref_ex = df_comp.loc[0, "ex"]
ref_RM = df_comp.loc[0, "RM"]

# Verificação do Art 36
df_comp["Art36_OK"] = (df_comp["ex"] >= ref_ex) & (df_comp["RM"] < ref_RM)

# Aplica o formato monetário brasileiro
for col in ["VABF", "VACF", "PMBaC", "PMBC", "RM"]:
    df_comp[col] = df_comp[col].apply(bib.Auxiliares.formatar_brasileiro)

# Concatenar primeira linha com linhas que atendem Art. 36
df_resultado = pd.concat([df_comp.head(1), df_comp[df_comp["Art36_OK"] == True]]).drop_duplicates()

display(df_resultado)
# Out:
#                  Tábua           VABF           VACF          PMBaC  \
# 0   IBGE 2024 F Extrap  89.269.813,56  26.559.779,79  62.710.033,77
# 14    GAM-71 F Suav 5%  90.403.464,51  27.161.498,72  63.241.965,79
# 15  GAM-71 F Suav 7,5%  90.979.928,63  27.346.816,77  63.633.111,87
#
#               PMBC              RM     ex  Art36_OK
# 0   129.874.648,70  192.584.682,47  29.31     False
# 14  127.346.536,42  190.588.502,21  29.35      True
# 15  128.425.760,95  192.058.872,82  29.59      True

# %% [markdown]
# ### PNI

# %%
# Calculando a RM e testando o Art. 36 para a base cadastral

# Filtrar a base masculina
base_fem_bimodal = base_cadastral_bimodal[base_cadastral_bimodal["Gênero"] == "Feminino"]

# Separar bases para PMBaC e PMBC
base_PMBaC = base_fem_bimodal[base_fem_bimodal["Idade"] < 62]
base_PMBC = base_fem_bimodal[base_fem_bimodal["Idade"] >= 62]

# Listas locais para armazenar resultados
lista_vabf, lista_vacf, lista_ex = [], [], []
lista_PMBAC, lista_PMBC, lista_RM = [], [], []

# Loop para iterar sobre as tábuas e calcular a reserva matemática
for tabua in tabuas_femininas:

    # Probabilidade de morte da tábua
    vetor_qx = df_tabuas_fem[tabua]
    if vetor_qx.dtype == object:
        vetor_qx = vetor_qx.str.replace(",", ".").astype(float)

    # Calcular a tábua de vida
    tabua_de_vida = bib.Calculos.calcular_tabua(vetor_qx)

    # Calcular PMBaC
    vabf_pmbac = bib.Calculos.VABF_PMBaC(base_PMBaC, tabua_de_vida, 0.05, 0.01)
    vacf_pmbac = bib.Calculos.VACF_PMBaC_PNI(base_PMBaC, tabua_de_vida, vabf_pmbac, 0.05, 0.01)

    # PMBaC individual (cada ativo)
    PMBaC_individual = vabf_pmbac - vacf_pmbac

    # PMBaC total (soma de todos os ativos)
    PMBaC_total = np.sum(PMBaC_individual)

    # Calcular PMBC
    PMBC_individual = bib.Calculos.VABF_PMBC(base_PMBC, tabua_de_vida, 0.05, 0.01)

    # PMBC total (soma de todos os aposentados)
    PMBC_total = np.sum(PMBC_individual)

    # Cálculo RM TOTAL
    RM_total = PMBaC_total + PMBC_total

    # Obtém a expectativa de vida na idade média
    ex_im = tabua_de_vida.loc[idade_media_bimodal,"ex"]

    # Adiciona os valores as suas devidas listas
    lista_vabf.append(np.sum(vabf_pmbac))
    lista_vacf.append(np.sum(vacf_pmbac))
    lista_PMBAC.append(PMBaC_total)
    lista_PMBC.append(PMBC_total)
    lista_RM.append(RM_total)
    lista_ex.append(round(ex_im, 2))

# DataFrame com os resultados
df_comp = pd.DataFrame({"Tábua": tabuas_femininas, "VABF": lista_vabf, "VACF": lista_vacf,
                        "PMBaC": lista_PMBAC, "PMBC": lista_PMBC, "RM": lista_RM,"ex": lista_ex})

# Comparar com a primeira linha
ref_ex = df_comp.loc[0, "ex"]
ref_RM = df_comp.loc[0, "RM"]

# Verificação do Art 36
df_comp["Art36_OK"] = (df_comp["ex"] >= ref_ex) & (df_comp["RM"] < ref_RM)

# Aplica o formato monetário brasileiro
for col in ["VABF", "VACF", "PMBaC", "PMBC", "RM"]:
    df_comp[col] = df_comp[col].apply(bib.Auxiliares.formatar_brasileiro)

# Concatenar primeira linha com linhas que atendem Art. 36
df_resultado = pd.concat([df_comp.head(1), df_comp[df_comp["Art36_OK"] == True]]).drop_duplicates()

display(df_resultado)
# Out:
#                  Tábua           VABF           VACF         PMBaC  \
# 0   IBGE 2024 F Extrap  89.269.813,56  82.274.367,29  6.995.446,28
# 7        AT-83 Basic F  92.802.720,76  87.738.836,68  5.063.884,08
# 14    GAM-71 F Suav 5%  90.403.464,51  85.120.695,75  5.282.768,75
# 15  GAM-71 F Suav 7,5%  90.979.928,63  85.733.396,69  5.246.531,94
# 16   GAM-71 F Suav 10%  91.568.462,60  86.358.404,07  5.210.058,53
# 25           RP-2000 F  91.375.847,72  86.588.561,21  4.787.286,51
#
#               PMBC              RM     ex  Art36_OK
# 0   129.874.648,70  136.870.094,98  29.31     False
# 7   131.083.857,33  136.147.741,41  30.25      True
# 14  127.346.536,42  132.629.305,17  29.35      True
# 15  128.425.760,95  133.672.292,89  29.59      True
# 16  129.534.297,36  134.744.355,89  29.83      True
# 25  130.216.264,52  135.003.551,03  29.84      True

# %% [markdown]
# # Reservas matemáticas - base jovem

# %%
# Calcular idade média
idade_media_jovem = int(base_cadastral_jovem["Idade"].mean())

# %% [markdown]
# ## Masculino

# %% [markdown]
# ### IEN

# %%
# Calculando a RM e testando o Art. 36 para a base cadastral

# Filtrar a base masculina
base_masc_jovem = base_cadastral_jovem[base_cadastral_jovem["Gênero"] == "Masculino"]

# Separar bases para PMBaC e PMBC
base_PMBaC = base_masc_jovem[base_masc_jovem["Idade"] < 65]
base_PMBC = base_masc_jovem[base_masc_jovem["Idade"] >= 65]

# Listas locais para armazenar resultados
lista_vabf, lista_vacf, lista_ex = [], [], []
lista_PMBAC, lista_PMBC, lista_RM = [], [], []

# Loop para iterar sobre as tábuas e calcular a reserva matemática
for tabua in tabuas_masculinas:

    # Probabilidade de morte da tábua
    vetor_qx = df_tabuas_masc[tabua]

    # Calcular a tábua de vida
    tabua_de_vida = bib.Calculos.calcular_tabua(vetor_qx)

    # Calcular PMBaC
    vabf_pmbac = bib.Calculos.VABF_PMBaC(base_PMBaC, tabua_de_vida, 0.05, 0.01)
    vacf_pmbac = bib.Calculos.VACF_PMBaC_INE(base_PMBaC, tabua_de_vida, vabf_pmbac, 0.05)

    # PMBaC individual (cada ativo)
    PMBaC_individual = vabf_pmbac - vacf_pmbac

    # PMBaC total (soma de todos os ativos)
    PMBaC_total = np.sum(PMBaC_individual)

    # Calcular PMBC
    PMBC_individual = bib.Calculos.VABF_PMBC(base_PMBC, tabua_de_vida, 0.05, 0.01)

    # PMBC total (soma de todos os aposentados)
    PMBC_total = np.sum(PMBC_individual)

    # Cálculo RM TOTAL
    RM_total = PMBaC_total + PMBC_total

    # Obtém a expectativa de vida na idade média
    ex_im = tabua_de_vida.loc[idade_media_jovem,"ex"]

    # Adiciona os valores as suas devidas listas
    lista_vabf.append(np.sum(vabf_pmbac))
    lista_vacf.append(np.sum(vacf_pmbac))
    lista_PMBAC.append(PMBaC_total)
    lista_PMBC.append(PMBC_total)
    lista_RM.append(RM_total)
    lista_ex.append(round(ex_im, 2))

# DataFrame com os resultados
df_comp = pd.DataFrame({"Tábua": tabuas_masculinas, "VABF": lista_vabf, "VACF": lista_vacf,
                        "PMBaC": lista_PMBAC, "PMBC": lista_PMBC, "RM": lista_RM,"ex": lista_ex})

# Comparar com a primeira linha
ref_ex = df_comp.loc[0, "ex"]
ref_RM = df_comp.loc[0, "RM"]

# Verificação do Art 36
df_comp["Art36_OK"] = (df_comp["ex"] >= ref_ex) & (df_comp["RM"] < ref_RM)

# Aplica o formato monetário brasileiro
for col in ["VABF", "VACF", "PMBaC", "PMBC", "RM"]:
    df_comp[col] = df_comp[col].apply(bib.Auxiliares.formatar_brasileiro)

#df_comp
# Concatenar primeira linha com linhas que atendem Art. 36
df_resultado = pd.concat([df_comp.head(1), df_comp[df_comp["Art36_OK"] == True]]).drop_duplicates()
display(df_resultado)
# Out:
#                             Tábua           VABF           VACF  \
# 0              IBGE 2024 Extrap M  58.182.518,57  23.349.847,32
# 11  IBGE 2019 Extrap. A Agrav 19%  58.107.963,40  23.441.736,60
# 19           AT-2000 M Agrav. 33%  59.197.312,57  24.282.389,12
# 22                          AT-55  57.216.218,64  23.492.211,62
# 23                 AT-55 Suave 5%  58.656.243,98  24.125.877,99
# 24                  AT-83 Basic M  58.821.974,24  24.287.468,13
# 25       AT-83 Basic M Suave 2,5%  59.497.936,67  24.584.638,06
# 31    BR-EMSmt-v.2021 M Agrav 24%  58.858.809,11  24.047.866,15
# 36                         GKM-95  57.384.114,59  23.490.713,34
# 39        Prudential-50 Suav. 16%  58.672.028,75  24.072.938,03
# 63                M-95 H Suave 6%  58.576.407,67  23.920.922,64
#
#             PMBaC           PMBC             RM     ex  Art36_OK
# 0   34.832.671,25  10.765.566,19  45.598.237,44  43.55     False
# 11  34.666.226,79  10.868.002,82  45.534.229,61  43.60      True
# ...

# %% [markdown]
# ### CUP

# %%
# Calculando a RM e testando o Art. 36 para a base cadastral

# Filtrar a base masculina
base_masc_jovem = base_cadastral_jovem[base_cadastral_jovem["Gênero"] == "Masculino"]

# Separar bases para PMBaC e PMBC
base_PMBaC = base_masc_jovem[base_masc_jovem["Idade"] < 65]
base_PMBC = base_masc_jovem[base_masc_jovem["Idade"] >= 65]

# Listas locais para armazenar resultados
lista_vabf, lista_vacf, lista_ex = [], [], []
lista_PMBAC, lista_PMBC, lista_RM = [], [], []

# Loop para iterar sobre as tábuas e calcular a reserva matemática
for tabua in tabuas_masculinas:

    # Probabilidade de morte da tábua
    vetor_qx = df_tabuas_masc[tabua]

    # Calcular a tábua de vida
    tabua_de_vida = bib.Calculos.calcular_tabua(vetor_qx)

    # Calcular PMBaC
    vabf_pmbac = bib.Calculos.VABF_PMBaC(base_PMBaC, tabua_de_vida, 0.05, 0.01)
    vacf_pmbac = bib.Calculos.VACF_PMBaC_CUP(base_PMBaC, vabf_pmbac)

    # PMBaC individual (cada ativo)
    PMBaC_individual = vabf_pmbac - vacf_pmbac

    # PMBaC total (soma de todos os ativos)
    PMBaC_total = np.sum(PMBaC_individual)

    # Calcular PMBC
    PMBC_individual = bib.Calculos.VABF_PMBC(base_PMBC, tabua_de_vida, 0.05, 0.01)

    # PMBC total (soma de todos os aposentados)
    PMBC_total = np.sum(PMBC_individual)

    # Cálculo RM TOTAL
    RM_total = PMBaC_total + PMBC_total

    # Obtém a expectativa de vida na idade média
    ex_im = tabua_de_vida.loc[idade_media_jovem,"ex"]

    # Adiciona os valores as suas devidas listas
    lista_vabf.append(np.sum(vabf_pmbac))
    lista_vacf.append(np.sum(vacf_pmbac))
    lista_PMBAC.append(PMBaC_total)
    lista_PMBC.append(PMBC_total)
    lista_RM.append(RM_total)
    lista_ex.append(round(ex_im, 2))

# DataFrame com os resultados
df_comp = pd.DataFrame({"Tábua": tabuas_masculinas, "VABF": lista_vabf, "VACF": lista_vacf,
                        "PMBaC": lista_PMBAC, "PMBC": lista_PMBC, "RM": lista_RM,"ex": lista_ex})

# Comparar com a primeira linha
ref_ex = df_comp.loc[0, "ex"]
ref_RM = df_comp.loc[0, "RM"]

# Verificação do Art 36
df_comp["Art36_OK"] = (df_comp["ex"] >= ref_ex) & (df_comp["RM"] < ref_RM)

# Aplica o formato monetário brasileiro
for col in ["VABF", "VACF", "PMBaC", "PMBC", "RM"]:
    df_comp[col] = df_comp[col].apply(bib.Auxiliares.formatar_brasileiro)

# Concatenar primeira linha com linhas que atendem Art. 36
df_resultado = pd.concat([df_comp.head(1), df_comp[df_comp["Art36_OK"] == True]]).drop_duplicates()

display(df_resultado)
# Out:
#                           Tábua           VABF           VACF          PMBaC  \
# 0            IBGE 2024 Extrap M  58.182.518,57  35.648.326,17  22.534.192,40
# 19         AT-2000 M Agrav. 33%  59.197.312,57  36.513.808,25  22.683.504,32
# 22                        AT-55  57.216.218,64  35.292.076,67  21.924.141,96
# 23               AT-55 Suave 5%  58.656.243,98  36.206.680,51  22.449.563,46
# 24                AT-83 Basic M  58.821.974,24  36.357.133,74  22.464.840,50
# 25     AT-83 Basic M Suave 2,5%  59.497.936,67  36.786.316,94  22.711.619,73
# 31  BR-EMSmt-v.2021 M Agrav 24%  58.858.809,11  36.266.112,21  22.592.696,90
# 36                       GKM-95  57.384.114,59  35.385.597,10  21.998.517,49
# 63              M-95 H Suave 6%  58.576.407,67  36.099.049,37  22.477.358,30
#
#              PMBC             RM     ex  Art36_OK
# 0   10.765.566,19  33.299.758,59  43.55     False
# 19   9.995.007,49  32.678.511,80  44.14      True
# ...

# %% [markdown]
# ### PNI

# %%
# Calculando a RM e testando o Art. 36 para a base cadastral

# Filtrar a base masculina
base_masc_jovem = base_cadastral_jovem[base_cadastral_jovem["Gênero"] == "Masculino"]

# Separar bases para PMBaC e PMBC
base_PMBaC = base_masc_jovem[base_masc_jovem["Idade"] < 65]
base_PMBC = base_masc_jovem[base_masc_jovem["Idade"] >= 65]

# Listas locais para armazenar resultados
lista_vabf, lista_vacf, lista_ex = [], [], []
lista_PMBAC, lista_PMBC, lista_RM = [], [], []

# Loop para iterar sobre as tábuas e calcular a reserva matemática
for tabua in tabuas_masculinas:

    # Probabilidade de morte da tábua
    vetor_qx = df_tabuas_masc[tabua]

    # Calcular a tábua de vida
    tabua_de_vida = bib.Calculos.calcular_tabua(vetor_qx)

    # Calcular PMBaC
    vabf_pmbac = bib.Calculos.VABF_PMBaC(base_PMBaC, tabua_de_vida, 0.05, 0.01)
    vacf_pmbac = bib.Calculos.VACF_PMBaC_PNI(base_PMBaC, tabua_de_vida, vabf_pmbac, 0.05, 0.01)

    # PMBaC individual (cada ativo)
    PMBaC_individual = vabf_pmbac - vacf_pmbac

    # PMBaC total (soma de todos os ativos)
    PMBaC_total = np.sum(PMBaC_individual)

    # Calcular PMBC
    PMBC_individual = bib.Calculos.VABF_PMBC(base_PMBC, tabua_de_vida, 0.05, 0.01)

    # PMBC total (soma de todos os aposentados)
    PMBC_total = np.sum(PMBC_individual)

    # Cálculo RM TOTAL
    RM_total = PMBaC_total + PMBC_total

    # Obtém a expectativa de vida na idade média
    ex_im = tabua_de_vida.loc[idade_media_jovem,"ex"]

    # Adiciona os valores as suas devidas listas
    lista_vabf.append(np.sum(vabf_pmbac))
    lista_vacf.append(np.sum(vacf_pmbac))
    lista_PMBAC.append(PMBaC_total)
    lista_PMBC.append(PMBC_total)
    lista_RM.append(RM_total)
    lista_ex.append(round(ex_im, 2))

# DataFrame com os resultados
df_comp = pd.DataFrame({"Tábua": tabuas_masculinas, "VABF": lista_vabf, "VACF": lista_vacf,
                        "PMBaC": lista_PMBAC, "PMBC": lista_PMBC, "RM": lista_RM,"ex": lista_ex})

# Comparar com a primeira linha
ref_ex = df_comp.loc[0, "ex"]
ref_RM = df_comp.loc[0, "RM"]

# Verificação do Art 36
df_comp["Art36_OK"] = (df_comp["ex"] >= ref_ex) & (df_comp["RM"] < ref_RM)

# Aplica o formato monetário brasileiro
for col in ["VABF", "VACF", "PMBaC", "PMBC", "RM"]:
    df_comp[col] = df_comp[col].apply(bib.Auxiliares.formatar_brasileiro)

# Concatenar primeira linha com linhas que atendem Art. 36
df_resultado = pd.concat([df_comp.head(1), df_comp[df_comp["Art36_OK"] == True]]).drop_duplicates()

display(df_resultado)
# Out:
#                               Tábua           VABF           VACF  \
# 0                IBGE 2024 Extrap M  58.182.518,57  38.739.156,76
# 11    IBGE 2019 Extrap. A Agrav 19%  58.107.963,40  39.109.503,27
# 12  IBGE 2019 Extrap. A Agrav 18,3%  58.360.456,13  39.294.115,48
# 19             AT-2000 M Agrav. 33%  59.197.312,57  40.580.622,46
# 22                            AT-55  57.216.218,64  39.425.265,53
# 23                   AT-55 Suave 5%  58.656.243,98  40.456.978,34
# 24                    AT-83 Basic M  58.821.974,24  40.707.274,86
# 25         AT-83 Basic M Suave 2,5%  59.497.936,67  41.190.524,99
# 30      BR-EMSmt-v.2021 M Agrav 20%  60.274.794,84  41.096.952,01
# 31      BR-EMSmt-v.2021 M Agrav 24%  58.858.809,11  40.067.974,72
# 36                           GKM-95  57.384.114,59  38.966.491,54
# 39          Prudential-50 Suav. 16%  58.672.028,75  40.469.560,97
# 40          Prudential-50 Suav. 17%  59.021.362,79  40.719.567,71
# ...

# %% [markdown]
# ## Feminino

# %% [markdown]
# ### INE

# %%
# Calculando a RM e testando o Art. 36 para a base cadastral

# Filtrar a base masculina
base_fem_jovem = base_cadastral_jovem[base_cadastral_jovem["Gênero"] == "Feminino"]

# Separar bases para PMBaC e PMBC
base_PMBaC = base_fem_jovem[base_fem_jovem["Idade"] < 62]
base_PMBC = base_fem_jovem[base_fem_jovem["Idade"] >= 62]

# Listas locais para armazenar resultados
lista_vabf, lista_vacf, lista_ex = [], [], []
lista_PMBAC, lista_PMBC, lista_RM = [], [], []

# Loop para iterar sobre as tábuas e calcular a reserva matemática
for tabua in tabuas_femininas:

    # Probabilidade de morte da tábua
    vetor_qx = df_tabuas_fem[tabua]
    if vetor_qx.dtype == object:
        vetor_qx = vetor_qx.str.replace(",", ".").astype(float)


    # Calcular a tábua de vida
    tabua_de_vida = bib.Calculos.calcular_tabua(vetor_qx)

    # Calcular PMBaC
    vabf_pmbac = bib.Calculos.VABF_PMBaC(base_PMBaC, tabua_de_vida, 0.05, 0.01)
    vacf_pmbac = bib.Calculos.VACF_PMBaC_INE(base_PMBaC, tabua_de_vida, vabf_pmbac, 0.05)

    # PMBaC individual (cada ativo)
    PMBaC_individual = vabf_pmbac - vacf_pmbac

    # PMBaC total (soma de todos os ativos)
    PMBaC_total = np.sum(PMBaC_individual)

    # Calcular PMBC
    PMBC_individual = bib.Calculos.VABF_PMBC(base_PMBC, tabua_de_vida, 0.05, 0.01)

    # PMBC total (soma de todos os aposentados)
    PMBC_total = np.sum(PMBC_individual)

    # Cálculo RM TOTAL
    RM_total = PMBaC_total + PMBC_total

    # Obtém a expectativa de vida na idade média
    ex_im = tabua_de_vida.loc[idade_media_jovem,'ex']

    # Adiciona os valores as suas devidas listas
    lista_vabf.append(np.sum(vabf_pmbac))
    lista_vacf.append(np.sum(vacf_pmbac))
    lista_PMBAC.append(PMBaC_total)
    lista_PMBC.append(PMBC_total)
    lista_RM.append(RM_total)
    lista_ex.append(round(ex_im, 2))

# DataFrame com os resultados
df_comp = pd.DataFrame({'Tábua': tabuas_femininas, 'VABF': lista_vabf, 'VACF': lista_vacf,
                        'PMBaC': lista_PMBAC, 'PMBC': lista_PMBC, 'RM': lista_RM,'ex': lista_ex})

# Comparar com a primeira linha
ref_ex = df_comp.loc[0, 'ex']
ref_RM = df_comp.loc[0, 'RM']

# Verificação do Art 36
df_comp['Art36_OK'] = (df_comp['ex'] >= ref_ex) & (df_comp['RM'] < ref_RM)

# Aplica o formato monetário brasileiro
for col in ['VABF', 'VACF', 'PMBaC', 'PMBC', 'RM']:
    df_comp[col] = df_comp[col].apply(bib.Auxiliares.formatar_brasileiro)
#df_comp
# Concatenar primeira linha com linhas que atendem Art. 36
df_resultado = pd.concat([df_comp.head(1), df_comp[df_comp["Art36_OK"] == True]]).drop_duplicates()

display(df_resultado)
# Out:
#                              Tábua           VABF           VACF  \
# 0               IBGE 2024 F Extrap  88.763.731,02  35.315.720,00
# 10  BR-EMSmt-v.2021 F Agrav. 21,5%  88.627.565,10  35.370.161,96
# 13                        GAM-71 F  89.693.720,07  35.982.863,45
# 47            Petros Suavizada 13%  88.619.600,20  35.513.628,07
# 48            Petros Suavizada 15%  89.205.642,56  35.761.109,50
#
#             PMBaC           PMBC             RM     ex  Art36_OK
# 0   53.448.011,02  13.489.284,01  66.937.295,03  48.70     False
# 10  53.257.403,15  13.582.468,42  66.839.871,57  48.84      True
# 13  53.710.856,62  12.840.332,48  66.551.189,09  48.87      True
# 47  53.105.972,12  13.122.105,66  66.228.077,79  48.71      True
# 48  53.444.533,06  13.243.945,46  66.688.478,52  48.94      True

# %% [markdown]
# ### PUC

# %%
# Calculando a RM e testando o Art. 36 para a base cadastral

# Filtrar a base masculina
base_fem_jovem = base_cadastral_jovem[base_cadastral_jovem["Gênero"] == "Feminino"]

# Separar bases para PMBaC e PMBC
base_PMBaC = base_fem_jovem[base_fem_jovem["Idade"] < 62]
base_PMBC = base_fem_jovem[base_fem_jovem["Idade"] >= 62]

# Listas locais para armazenar resultados
lista_vabf, lista_vacf, lista_ex = [], [], []
lista_PMBAC, lista_PMBC, lista_RM = [], [], []

# Loop para iterar sobre as tábuas e calcular a reserva matemática
for tabua in tabuas_femininas:

    # Probabilidade de morte da tábua
    vetor_qx = df_tabuas_fem[tabua]
    if vetor_qx.dtype == object:
        vetor_qx = vetor_qx.str.replace(",", ".").astype(float)

    # Calcular a tábua de vida
    tabua_de_vida = bib.Calculos.calcular_tabua(vetor_qx)

    # Calcular PMBaC
    vabf_pmbac = bib.Calculos.VABF_PMBaC(base_PMBaC, tabua_de_vida, 0.05, 0.01)
    vacf_pmbac = bib.Calculos.VACF_PMBaC_CUP(base_PMBaC, vabf_pmbac)

    # PMBaC individual (cada ativo)
    PMBaC_individual = vabf_pmbac - vacf_pmbac

    # PMBaC total (soma de todos os ativos)
    PMBaC_total = np.sum(PMBaC_individual)

    # Calcular PMBC
    PMBC_individual = bib.Calculos.VABF_PMBC(base_PMBC, tabua_de_vida, 0.05, 0.01)

    # PMBC total (soma de todos os aposentados)
    PMBC_total = np.sum(PMBC_individual)

    # Cálculo RM TOTAL
    RM_total = PMBaC_total + PMBC_total

    # Obtém a expectativa de vida na idade média
    ex_im = tabua_de_vida.loc[idade_media_jovem,"ex"]

    # Adiciona os valores as suas devidas listas
    lista_vabf.append(np.sum(vabf_pmbac))
    lista_vacf.append(np.sum(vacf_pmbac))
    lista_PMBAC.append(PMBaC_total)
    lista_PMBC.append(PMBC_total)
    lista_RM.append(RM_total)
    lista_ex.append(round(ex_im, 2))

# DataFrame com os resultados
df_comp = pd.DataFrame({"Tábua": tabuas_femininas, "VABF": lista_vabf, "VACF": lista_vacf,
                        "PMBaC": lista_PMBAC, "PMBC": lista_PMBC, "RM": lista_RM,"ex": lista_ex})

# Comparar com a primeira linha
ref_ex = df_comp.loc[0, "ex"]
ref_RM = df_comp.loc[0, "RM"]

# Verificação do Art 36
df_comp["Art36_OK"] = (df_comp["ex"] >= ref_ex) & (df_comp["RM"] < ref_RM)

# Aplica o formato monetário brasileiro
for col in ["VABF", "VACF", "PMBaC", "PMBC", "RM"]:
    df_comp[col] = df_comp[col].apply(bib.Auxiliares.formatar_brasileiro)

# Concatenar primeira linha com linhas que atendem Art. 36
df_resultado = pd.concat([df_comp.head(1), df_comp[df_comp["Art36_OK"] == True]]).drop_duplicates()

display(df_resultado)
# Out:
#                              Tábua           VABF           VACF  \
# 0               IBGE 2024 F Extrap  88.763.731,02  52.581.945,32
# 10  BR-EMSmt-v.2021 F Agrav. 21,5%  88.627.565,10  52.555.273,50
# 13                        GAM-71 F  89.693.720,07  53.287.184,47
# 47            Petros Suavizada 13%  88.619.600,20  52.620.001,77
# 48            Petros Suavizada 15%  89.205.642,56  52.975.079,46
#
#             PMBaC           PMBC             RM     ex  Art36_OK
# 0   36.181.785,70  13.489.284,01  49.671.069,71  48.70     False
# 10  36.072.291,60  13.582.468,42  49.654.760,02  48.84      True
# 13  36.406.535,60  12.840.332,48  49.246.868,07  48.87      True
# 47  35.999.598,43  13.122.105,66  49.121.704,09  48.71      True
# 48  36.230.563,10  13.243.945,46  49.474.508,56  48.94      True

# %% [markdown]
# ### PNI

# %%
# Calculando a RM e testando o Art. 36 para a base cadastral

# Filtrar a base masculina
base_fem_jovem = base_cadastral_jovem[base_cadastral_jovem["Gênero"] == "Feminino"]

# Separar bases para PMBaC e PMBC
base_PMBaC = base_fem_jovem[base_fem_jovem["Idade"] < 62]
base_PMBC = base_fem_jovem[base_fem_jovem["Idade"] >= 62]

# Listas locais para armazenar resultados
lista_vabf, lista_vacf, lista_ex = [], [], []
lista_PMBAC, lista_PMBC, lista_RM = [], [], []

# Loop para iterar sobre as tábuas e calcular a reserva matemática
for tabua in tabuas_femininas:

    # Probabilidade de morte da tábua
    vetor_qx = df_tabuas_fem[tabua]
    if vetor_qx.dtype == object:
        vetor_qx = vetor_qx.str.replace(",", ".").astype(float)

    # Calcular a tábua de vida
    tabua_de_vida = bib.Calculos.calcular_tabua(vetor_qx)

    # Calcular PMBaC
    vabf_pmbac = bib.Calculos.VABF_PMBaC(base_PMBaC, tabua_de_vida, 0.05, 0.01)
    vacf_pmbac = bib.Calculos.VACF_PMBaC_PNI(base_PMBaC, tabua_de_vida, vabf_pmbac, 0.05, 0.01)

    # PMBaC individual (cada ativo)
    PMBaC_individual = vabf_pmbac - vacf_pmbac

    # PMBaC total (soma de todos os ativos)
    PMBaC_total = np.sum(PMBaC_individual)

    # Calcular PMBC
    PMBC_individual = bib.Calculos.VABF_PMBC(base_PMBC, tabua_de_vida, 0.05, 0.01)

    # PMBC total (soma de todos os aposentados)
    PMBC_total = np.sum(PMBC_individual)

    # Cálculo RM TOTAL
    RM_total = PMBaC_total + PMBC_total

    # Obtém a expectativa de vida na idade média
    ex_im = tabua_de_vida.loc[idade_media_jovem,"ex"]

    # Adiciona os valores as suas devidas listas
    lista_vabf.append(np.sum(vabf_pmbac))
    lista_vacf.append(np.sum(vacf_pmbac))
    lista_PMBAC.append(PMBaC_total)
    lista_PMBC.append(PMBC_total)
    lista_RM.append(RM_total)
    lista_ex.append(round(ex_im, 2))

# DataFrame com os resultados
df_comp = pd.DataFrame({"Tábua": tabuas_femininas, "VABF": lista_vabf, "VACF": lista_vacf,
                        "PMBaC": lista_PMBAC, "PMBC": lista_PMBC, "RM": lista_RM,"ex": lista_ex})

# Comparar com a primeira linha
ref_ex = df_comp.loc[0, "ex"]
ref_RM = df_comp.loc[0, "RM"]

# Verificação do Art 36
df_comp["Art36_OK"] = (df_comp["ex"] >= ref_ex) & (df_comp["RM"] < ref_RM)

# Aplica o formato monetário brasileiro
for col in ["VABF", "VACF", "PMBaC", "PMBC", "RM"]:
    df_comp[col] = df_comp[col].apply(bib.Auxiliares.formatar_brasileiro)

# Concatenar primeira linha com linhas que atendem Art. 36
df_resultado = pd.concat([df_comp.head(1), df_comp[df_comp["Art36_OK"] == True]]).drop_duplicates()

display(df_resultado)
# Out:
#                              Tábua           VABF           VACF  \
# 0               IBGE 2024 F Extrap  88.763.731,02  61.513.584,41
# 10  BR-EMSmt-v.2021 F Agrav. 21,5%  88.627.565,10  61.533.091,25
# 13                        GAM-71 F  89.693.720,07  62.585.621,71
# 14                GAM-71 F Suav 5%  90.910.517,72  63.461.560,40
# 47            Petros Suavizada 13%  88.619.600,20  61.887.002,89
# 48            Petros Suavizada 15%  89.205.642,56  62.307.277,38
# 49            Petros Suavizada 17%  89.801.786,54  62.734.746,52
#
#             PMBaC           PMBC             RM     ex  Art36_OK
# 0   27.250.146,61  13.489.284,01  40.739.430,62  48.70     False
# 10  27.094.473,85  13.582.468,42  40.676.942,28  48.84      True
# 13  27.108.098,36  12.840.332,48  39.948.430,84  48.87      True
# 14  27.448.957,32  13.107.764,72  40.556.722,03  49.36      True
# 47  26.732.597,30  13.122.105,66  39.854.702,97  48.71      True
# ...

# %% [markdown]
# # Reservas matemáticas - base idosa

# %%
# Calcular idade média
idade_media_idosa = int(base_cadastral_idosa["Idade"].mean())

# %% [markdown]
# ## Masculino

# %% [markdown]
# ### IEN

# %%
# Calculando a RM e testando o Art. 36 para a base cadastral

# Filtrar a base masculina
base_masc_idosa = base_cadastral_idosa[base_cadastral_idosa["Gênero"] == "Masculino"]

# Separar bases para PMBaC e PMBC
base_PMBaC = base_masc_idosa[base_masc_idosa["Idade"] < 65]
base_PMBC = base_masc_idosa[base_masc_idosa["Idade"] >= 65]

# Listas locais para armazenar resultados
lista_vabf, lista_vacf, lista_ex = [], [], []
lista_PMBAC, lista_PMBC, lista_RM = [], [], []

# Loop para iterar sobre as tábuas e calcular a reserva matemática
for tabua in tabuas_masculinas:

    # Probabilidade de morte da tábua
    vetor_qx = df_tabuas_masc[tabua]

    # Calcular a tábua de vida
    tabua_de_vida = bib.Calculos.calcular_tabua(vetor_qx)

    # Calcular PMBaC
    vabf_pmbac = bib.Calculos.VABF_PMBaC(base_PMBaC, tabua_de_vida, 0.05, 0.01)
    vacf_pmbac = bib.Calculos.VACF_PMBaC_INE(base_PMBaC, tabua_de_vida, vabf_pmbac, 0.05)

    # PMBaC individual (cada ativo)
    PMBaC_individual = vabf_pmbac - vacf_pmbac

    # PMBaC total (soma de todos os ativos)
    PMBaC_total = np.sum(PMBaC_individual)

    # Calcular PMBC
    PMBC_individual = bib.Calculos.VABF_PMBC(base_PMBC, tabua_de_vida, 0.05, 0.01)

    # PMBC total (soma de todos os aposentados)
    PMBC_total = np.sum(PMBC_individual)

    # Cálculo RM TOTAL
    RM_total = PMBaC_total + PMBC_total

    # Obtém a expectativa de vida na idade média
    ex_im = tabua_de_vida.loc[idade_media_idosa,"ex"]

    # Adiciona os valores as suas devidas listas
    lista_vabf.append(np.sum(vabf_pmbac))
    lista_vacf.append(np.sum(vacf_pmbac))
    lista_PMBAC.append(PMBaC_total)
    lista_PMBC.append(PMBC_total)
    lista_RM.append(RM_total)
    lista_ex.append(round(ex_im, 2))

# DataFrame com os resultados
df_comp = pd.DataFrame({"Tábua": tabuas_masculinas, "VABF": lista_vabf, "VACF": lista_vacf,
                        "PMBaC": lista_PMBAC, "PMBC": lista_PMBC, "RM": lista_RM,"ex": lista_ex})

# Comparar com a primeira linha
ref_ex = df_comp.loc[0, "ex"]
ref_RM = df_comp.loc[0, "RM"]

# Verificação do Art 36
df_comp["Art36_OK"] = (df_comp["ex"] >= ref_ex) & (df_comp["RM"] < ref_RM)

# Aplica o formato monetário brasileiro
for col in ["VABF", "VACF", "PMBaC", "PMBC", "RM"]:
    df_comp[col] = df_comp[col].apply(bib.Auxiliares.formatar_brasileiro)

# Concatenar primeira linha com linhas que atendem Art. 36
df_resultado = pd.concat([df_comp.head(1), df_comp[df_comp["Art36_OK"] == True]]).drop_duplicates()

display(df_resultado)
# Out:
#                  Tábua           VABF          VACF          PMBaC  \
# 0   IBGE 2024 Extrap M  78.827.609,81  6.796.668,36  72.030.941,45
# 60             TR 2025  80.245.101,68  6.955.010,69  73.290.090,99
#
#               PMBC              RM     ex  Art36_OK
# 0   119.430.898,52  191.461.839,97  17.21     False
# 60  117.939.371,90  191.229.462,89  17.48      True

# %% [markdown]
# ### CUP

# %%
# Calculando a RM e testando o Art. 36 para a base cadastral

# Filtrar a base masculina
base_masc_idosa = base_cadastral_idosa[base_cadastral_idosa["Gênero"] == "Masculino"]

# Separar bases para PMBaC e PMBC
base_PMBaC = base_masc_idosa[base_masc_idosa["Idade"] < 65]
base_PMBC = base_masc_idosa[base_masc_idosa["Idade"] >= 65]

# Listas locais para armazenar resultados
lista_vabf, lista_vacf, lista_ex = [], [], []
lista_PMBAC, lista_PMBC, lista_RM = [], [], []

# Loop para iterar sobre as tábuas e calcular a reserva matemática
for tabua in tabuas_masculinas:

    # Probabilidade de morte da tábua
    vetor_qx = df_tabuas_masc[tabua]

    # Calcular a tábua de vida
    tabua_de_vida = bib.Calculos.calcular_tabua(vetor_qx)

    # Calcular PMBaC
    vabf_pmbac = bib.Calculos.VABF_PMBaC(base_PMBaC, tabua_de_vida, 0.05, 0.01)
    vacf_pmbac = bib.Calculos.VACF_PMBaC_CUP(base_PMBaC, vabf_pmbac)

    # PMBaC individual (cada ativo)
    PMBaC_individual = vabf_pmbac - vacf_pmbac

    # PMBaC total (soma de todos os ativos)
    PMBaC_total = np.sum(PMBaC_individual)

    # Calcular PMBC
    PMBC_individual = bib.Calculos.VABF_PMBC(base_PMBC, tabua_de_vida, 0.05, 0.01)

    # PMBC total (soma de todos os aposentados)
    PMBC_total = np.sum(PMBC_individual)

    # Cálculo RM TOTAL
    RM_total = PMBaC_total + PMBC_total

    # Obtém a expectativa de vida na idade média
    ex_im = tabua_de_vida.loc[idade_media_idosa,"ex"]

    # Adiciona os valores as suas devidas listas
    lista_vabf.append(np.sum(vabf_pmbac))
    lista_vacf.append(np.sum(vacf_pmbac))
    lista_PMBAC.append(PMBaC_total)
    lista_PMBC.append(PMBC_total)
    lista_RM.append(RM_total)
    lista_ex.append(round(ex_im, 2))

# DataFrame com os resultados
df_comp = pd.DataFrame({"Tábua": tabuas_masculinas, "VABF": lista_vabf, "VACF": lista_vacf,
                        "PMBaC": lista_PMBAC, "PMBC": lista_PMBC, "RM": lista_RM,"ex": lista_ex})

# Comparar com a primeira linha
ref_ex = df_comp.loc[0, "ex"]
ref_RM = df_comp.loc[0, "RM"]

# Verificação do Art 36
df_comp["Art36_OK"] = (df_comp["ex"] >= ref_ex) & (df_comp["RM"] < ref_RM)

# Aplica o formato monetário brasileiro
for col in ["VABF", "VACF", "PMBaC", "PMBC", "RM"]:
    df_comp[col] = df_comp[col].apply(bib.Auxiliares.formatar_brasileiro)

# Concatenar primeira linha com linhas que atendem Art. 36
df_resultado = pd.concat([df_comp.head(1), df_comp[df_comp["Art36_OK"] == True]]).drop_duplicates()

display(df_resultado)
# Out:
#                  Tábua           VABF           VACF          PMBaC  \
# 0   IBGE 2024 Extrap M  78.827.609,81  17.183.905,45  61.643.704,36
# 60             TR 2025  80.245.101,68  17.516.812,45  62.728.289,23
#
#               PMBC              RM     ex  Art36_OK
# 0   119.430.898,52  181.074.602,87  17.21     False
# 60  117.939.371,90  180.667.661,13  17.48      True

# %% [markdown]
# ### PNI

# %%
# Calculando a RM e testando o Art. 36 para a base cadastral

# Filtrar a base masculina
base_masc_idosa = base_cadastral_idosa[base_cadastral_idosa["Gênero"] == "Masculino"]

# Separar bases para PMBaC e PMBC
base_PMBaC = base_masc_idosa[base_masc_idosa["Idade"] < 65]
base_PMBC = base_masc_idosa[base_masc_idosa["Idade"] >= 65]

# Listas locais para armazenar resultados
lista_vabf, lista_vacf, lista_ex = [], [], []
lista_PMBAC, lista_PMBC, lista_RM = [], [], []

# Loop para iterar sobre as tábuas e calcular a reserva matemática
for tabua in tabuas_masculinas:

    # Probabilidade de morte da tábua
    vetor_qx = df_tabuas_masc[tabua]

    # Calcular a tábua de vida
    tabua_de_vida = bib.Calculos.calcular_tabua(vetor_qx)

    # Calcular PMBaC
    vabf_pmbac = bib.Calculos.VABF_PMBaC(base_PMBaC, tabua_de_vida, 0.05, 0.01)
    vacf_pmbac = bib.Calculos.VACF_PMBaC_PNI(base_PMBaC, tabua_de_vida, vabf_pmbac, 0.05, 0.01)

    # PMBaC individual (cada ativo)
    PMBaC_individual = vabf_pmbac - vacf_pmbac

    # PMBaC total (soma de todos os ativos)
    PMBaC_total = np.sum(PMBaC_individual)

    # Calcular PMBC
    PMBC_individual = bib.Calculos.VABF_PMBC(base_PMBC, tabua_de_vida, 0.05, 0.01)

    # PMBC total (soma de todos os aposentados)
    PMBC_total = np.sum(PMBC_individual)

    # Cálculo RM TOTAL
    RM_total = PMBaC_total + PMBC_total

    # Obtém a expectativa de vida na idade média
    ex_im = tabua_de_vida.loc[idade_media_idosa,"ex"]

    # Adiciona os valores as suas devidas listas
    lista_vabf.append(np.sum(vabf_pmbac))
    lista_vacf.append(np.sum(vacf_pmbac))
    lista_PMBAC.append(PMBaC_total)
    lista_PMBC.append(PMBC_total)
    lista_RM.append(RM_total)
    lista_ex.append(round(ex_im, 2))

# DataFrame com os resultados
df_comp = pd.DataFrame({"Tábua": tabuas_masculinas, "VABF": lista_vabf, "VACF": lista_vacf,
                        "PMBaC": lista_PMBAC, "PMBC": lista_PMBC, "RM": lista_RM,"ex": lista_ex})

# Comparar com a primeira linha
ref_ex = df_comp.loc[0, "ex"]
ref_RM = df_comp.loc[0, "RM"]

# Verificação do Art 36
df_comp["Art36_OK"] = (df_comp["ex"] >= ref_ex) & (df_comp["RM"] < ref_RM)

# Aplica o formato monetário brasileiro
for col in ["VABF", "VACF", "PMBaC", "PMBC", "RM"]:
    df_comp[col] = df_comp[col].apply(bib.Auxiliares.formatar_brasileiro)

# Concatenar primeira linha com linhas que atendem Art. 36
df_resultado = pd.concat([df_comp.head(1), df_comp[df_comp["Art36_OK"] == True]]).drop_duplicates()

display(df_resultado)
# Out:
#                           Tábua           VABF           VACF          PMBaC  \
# 0            IBGE 2024 Extrap M  78.827.609,81  56.213.191,68  22.614.418,13
# 28  BR-EMSmt-v.2021 M Agrav 10%  83.191.491,98  63.549.803,68  19.641.688,30
# 29  BR-EMSmt-v.2021 M Agrav 15%  81.446.235,69  61.882.461,80  19.563.773,88
# 42      Prudential-50 Suav. 19%  79.001.379,21  60.480.714,35  18.520.664,87
# 46                    RP-2000 M  85.328.400,17  68.073.858,16  17.254.542,02
# 49                    UP - 94 M  82.441.763,21  64.764.014,13  17.677.749,09
# 58    BR-EMSmt 2015 M Agrav 25%  80.958.047,17  60.665.576,56  20.292.470,61
# 60                      TR 2025  80.245.101,68  58.041.773,31  22.203.328,37
# 61                       Petros  86.627.054,50  68.695.972,44  17.931.082,06
#
#               PMBC              RM     ex  Art36_OK
# 0   119.430.898,52  142.045.316,64  17.21     False
# 28  121.711.237,71  141.352.926,01  17.86      True
# ...

# %% [markdown]
# ## Feminino

# %% [markdown]
# ### INE

# %%
# Calculando a RM e testando o Art. 36 para a base cadastral

# Filtrar a base masculina
base_fem_idosa = base_cadastral_idosa[base_cadastral_idosa["Gênero"] == "Feminino"]

# Separar bases para PMBaC e PMBC
base_PMBaC = base_fem_idosa[base_fem_idosa["Idade"] < 62]
base_PMBC = base_fem_idosa[base_fem_idosa["Idade"] >= 62]

# Listas locais para armazenar resultados
lista_vabf, lista_vacf, lista_ex = [], [], []
lista_PMBAC, lista_PMBC, lista_RM = [], [], []

# Loop para iterar sobre as tábuas e calcular a reserva matemática
for tabua in tabuas_femininas:

    # Probabilidade de morte da tábua
    vetor_qx = df_tabuas_fem[tabua]
    if vetor_qx.dtype == object:
        vetor_qx = vetor_qx.str.replace(",", ".").astype(float)


    # Calcular a tábua de vida
    tabua_de_vida = bib.Calculos.calcular_tabua(vetor_qx)

    # Calcular PMBaC
    vabf_pmbac = bib.Calculos.VABF_PMBaC(base_PMBaC, tabua_de_vida, 0.05, 0.01)
    vacf_pmbac = bib.Calculos.VACF_PMBaC_INE(base_PMBaC, tabua_de_vida, vabf_pmbac, 0.05)

    # PMBaC individual (cada ativo)
    PMBaC_individual = vabf_pmbac - vacf_pmbac

    # PMBaC total (soma de todos os ativos)
    PMBaC_total = np.sum(PMBaC_individual)

    # Calcular PMBC
    PMBC_individual = bib.Calculos.VABF_PMBC(base_PMBC, tabua_de_vida, 0.05, 0.01)

    # PMBC total (soma de todos os aposentados)
    PMBC_total = np.sum(PMBC_individual)

    # Cálculo RM TOTAL
    RM_total = PMBaC_total + PMBC_total

    # Obtém a expectativa de vida na idade média
    ex_im = tabua_de_vida.loc[idade_media_idosa,'ex']

    # Adiciona os valores as suas devidas listas
    lista_vabf.append(np.sum(vabf_pmbac))
    lista_vacf.append(np.sum(vacf_pmbac))
    lista_PMBAC.append(PMBaC_total)
    lista_PMBC.append(PMBC_total)
    lista_RM.append(RM_total)
    lista_ex.append(round(ex_im, 2))

# DataFrame com os resultados
df_comp = pd.DataFrame({'Tábua': tabuas_femininas, 'VABF': lista_vabf, 'VACF': lista_vacf,
                        'PMBaC': lista_PMBAC, 'PMBC': lista_PMBC, 'RM': lista_RM,'ex': lista_ex})

# Comparar com a primeira linha
ref_ex = df_comp.loc[0, 'ex']
ref_RM = df_comp.loc[0, 'RM']

# Verificação do Art 36
df_comp['Art36_OK'] = (df_comp['ex'] >= ref_ex) & (df_comp['RM'] < ref_RM)

# Aplica o formato monetário brasileiro
for col in ['VABF', 'VACF', 'PMBaC', 'PMBC', 'RM']:
    df_comp[col] = df_comp[col].apply(bib.Auxiliares.formatar_brasileiro)

# Concatenar primeira linha com linhas que atendem Art. 36
df_resultado = pd.concat([df_comp.head(1), df_comp[df_comp["Art36_OK"] == True]]).drop_duplicates()

display(df_resultado)
# Out:
#                  Tábua           VABF          VACF          PMBaC  \
# 0   IBGE 2024 F Extrap  95.689.648,33  9.488.434,68  86.201.213,65
# 54     M-95 M Suav. 7%  96.207.048,07  9.559.816,36  86.647.231,72
#
#               PMBC              RM     ex  Art36_OK
# 0   152.505.835,81  238.707.049,45  20.07     False
# 54  151.620.206,92  238.267.438,63  20.08      True

# %% [markdown]
# ### PUC

# %%
# Calculando a RM e testando o Art. 36 para a base cadastral

# Filtrar a base masculina
base_fem_idosa = base_cadastral_idosa[base_cadastral_idosa["Gênero"] == "Feminino"]

# Separar bases para PMBaC e PMBC
base_PMBaC = base_fem_idosa[base_fem_idosa["Idade"] < 62]
base_PMBC = base_fem_idosa[base_fem_idosa["Idade"] >= 62]

# Listas locais para armazenar resultados
lista_vabf, lista_vacf, lista_ex = [], [], []
lista_PMBAC, lista_PMBC, lista_RM = [], [], []

# Loop para iterar sobre as tábuas e calcular a reserva matemática
for tabua in tabuas_femininas:

    # Probabilidade de morte da tábua
    vetor_qx = df_tabuas_fem[tabua]
    if vetor_qx.dtype == object:
        vetor_qx = vetor_qx.str.replace(",", ".").astype(float)

    # Calcular a tábua de vida
    tabua_de_vida = bib.Calculos.calcular_tabua(vetor_qx)

    # Calcular PMBaC
    vabf_pmbac = bib.Calculos.VABF_PMBaC(base_PMBaC, tabua_de_vida, 0.05, 0.01)
    vacf_pmbac = bib.Calculos.VACF_PMBaC_CUP(base_PMBaC, vabf_pmbac)

    # PMBaC individual (cada ativo)
    PMBaC_individual = vabf_pmbac - vacf_pmbac

    # PMBaC total (soma de todos os ativos)
    PMBaC_total = np.sum(PMBaC_individual)

    # Calcular PMBC
    PMBC_individual = bib.Calculos.VABF_PMBC(base_PMBC, tabua_de_vida, 0.05, 0.01)

    # PMBC total (soma de todos os aposentados)
    PMBC_total = np.sum(PMBC_individual)

    # Cálculo RM TOTAL
    RM_total = PMBaC_total + PMBC_total

    # Obtém a expectativa de vida na idade média
    ex_im = tabua_de_vida.loc[idade_media_idosa,"ex"]

    # Adiciona os valores as suas devidas listas
    lista_vabf.append(np.sum(vabf_pmbac))
    lista_vacf.append(np.sum(vacf_pmbac))
    lista_PMBAC.append(PMBaC_total)
    lista_PMBC.append(PMBC_total)
    lista_RM.append(RM_total)
    lista_ex.append(round(ex_im, 2))

# DataFrame com os resultados
df_comp = pd.DataFrame({"Tábua": tabuas_femininas, "VABF": lista_vabf, "VACF": lista_vacf,
                        "PMBaC": lista_PMBAC, "PMBC": lista_PMBC, "RM": lista_RM,"ex": lista_ex})

# Comparar com a primeira linha
ref_ex = df_comp.loc[0, "ex"]
ref_RM = df_comp.loc[0, "RM"]

# Verificação do Art 36
df_comp["Art36_OK"] = (df_comp["ex"] >= ref_ex) & (df_comp["RM"] < ref_RM)

# Aplica o formato monetário brasileiro
for col in ["VABF", "VACF", "PMBaC", "PMBC", "RM"]:
    df_comp[col] = df_comp[col].apply(bib.Auxiliares.formatar_brasileiro)

# Concatenar primeira linha com linhas que atendem Art. 36
df_resultado = pd.concat([df_comp.head(1), df_comp[df_comp["Art36_OK"] == True]]).drop_duplicates()

display(df_resultado)
# Out:
#                  Tábua           VABF           VACF          PMBaC  \
# 0   IBGE 2024 F Extrap  95.689.648,33  21.132.561,36  74.557.086,97
# 54     M-95 M Suav. 7%  96.207.048,07  21.267.191,65  74.939.856,42
#
#               PMBC              RM     ex  Art36_OK
# 0   152.505.835,81  227.062.922,78  20.07     False
# 54  151.620.206,92  226.560.063,34  20.08      True

# %% [markdown]
# ### PNI

# %%
# Calculando a RM e testando o Art. 36 para a base cadastral

# Filtrar a base masculina
base_fem_idosa = base_cadastral_idosa[base_cadastral_idosa["Gênero"] == "Feminino"]

# Separar bases para PMBaC e PMBC
base_PMBaC = base_fem_idosa[base_fem_idosa["Idade"] < 62]
base_PMBC = base_fem_idosa[base_fem_idosa["Idade"] >= 62]

# Listas locais para armazenar resultados
lista_vabf, lista_vacf, lista_ex = [], [], []
lista_PMBAC, lista_PMBC, lista_RM = [], [], []

# Loop para iterar sobre as tábuas e calcular a reserva matemática
for tabua in tabuas_femininas:

    # Probabilidade de morte da tábua
    vetor_qx = df_tabuas_fem[tabua]
    if vetor_qx.dtype == object:
        vetor_qx = vetor_qx.str.replace(",", ".").astype(float)

    # Calcular a tábua de vida
    tabua_de_vida = bib.Calculos.calcular_tabua(vetor_qx)

    # Calcular PMBaC
    vabf_pmbac = bib.Calculos.VABF_PMBaC(base_PMBaC, tabua_de_vida, 0.05, 0.01)
    vacf_pmbac = bib.Calculos.VACF_PMBaC_PNI(base_PMBaC, tabua_de_vida, vabf_pmbac, 0.05, 0.01)

    # PMBaC individual (cada ativo)
    PMBaC_individual = vabf_pmbac - vacf_pmbac

    # PMBaC total (soma de todos os ativos)
    PMBaC_total = np.sum(PMBaC_individual)

    # Calcular PMBC
    PMBC_individual = bib.Calculos.VABF_PMBC(base_PMBC, tabua_de_vida, 0.05, 0.01)

    # PMBC total (soma de todos os aposentados)
    PMBC_total = np.sum(PMBC_individual)

    # Cálculo RM TOTAL
    RM_total = PMBaC_total + PMBC_total

    # Obtém a expectativa de vida na idade média
    ex_im = tabua_de_vida.loc[idade_media_idosa,"ex"]

    # Adiciona os valores as suas devidas listas
    lista_vabf.append(np.sum(vabf_pmbac))
    lista_vacf.append(np.sum(vacf_pmbac))
    lista_PMBAC.append(PMBaC_total)
    lista_PMBC.append(PMBC_total)
    lista_RM.append(RM_total)
    lista_ex.append(round(ex_im, 2))

# DataFrame com os resultados
df_comp = pd.DataFrame({"Tábua": tabuas_femininas, "VABF": lista_vabf, "VACF": lista_vacf,
                        "PMBaC": lista_PMBAC, "PMBC": lista_PMBC, "RM": lista_RM,"ex": lista_ex})

# Comparar com a primeira linha
ref_ex = df_comp.loc[0, "ex"]
ref_RM = df_comp.loc[0, "RM"]

# Verificação do Art 36
df_comp["Art36_OK"] = (df_comp["ex"] >= ref_ex) & (df_comp["RM"] < ref_RM)

# Aplica o formato monetário brasileiro
for col in ["VABF", "VACF", "PMBaC", "PMBC", "RM"]:
    df_comp[col] = df_comp[col].apply(bib.Auxiliares.formatar_brasileiro)

# Concatenar primeira linha com linhas que atendem Art. 36
df_resultado = pd.concat([df_comp.head(1), df_comp[df_comp["Art36_OK"] == True]]).drop_duplicates()

display(df_resultado)
# Out:
#                  Tábua            VABF           VACF          PMBaC  \
# 0   IBGE 2024 F Extrap   95.689.648,33  83.753.560,69  11.936.087,63
# 7        AT-83 Basic F   99.237.128,77  89.320.869,00   9.916.259,77
# 16   GAM-71 F Suav 10%   97.944.928,66  87.912.093,51  10.032.835,15
# 25           RP-2000 F   97.690.614,24  88.153.631,45   9.536.982,78
# 31                 CL5  100.869.688,99  90.373.347,72  10.496.341,26
# 54     M-95 M Suav. 7%   96.207.048,07  84.209.787,07  11.997.261,00
#
#               PMBC              RM     ex  Art36_OK
# 0   152.505.835,81  164.441.923,44  20.07     False
# 7   152.573.430,61  162.489.690,38  20.45      True
# 16  151.385.756,97  161.418.592,12  20.08      True
# 25  153.212.351,31  162.749.334,10  20.12      True
# 31  153.680.271,83  164.176.613,09  20.98      True
# 54  151.620.206,92  163.617.467,92  20.08      True

# %% [markdown]
# # $I$

# %% [markdown]
# ## Jovem

# %% [markdown]
# ### Tabuas

# %%
lista_tabua_pminf_masc = ["Prudential-50 Suav. 16%"

]



lista_tabua_exsup_masc = [
"IBGE 2024 Extrap M",
"IBGE 2021 Extrap M Suav 1%",
"IBGE 2019 Extrap. A",
"IBGE 2019 Extrap. A Agrav 19%",
"IBGE 2019 Extrap. A Agrav 18,3%",
"IBGE 2018 Extrap. A",
"AT-2000 (Suav 10%) M",
"AT-2000 M",
"AT-2000 M Agrav. 33%",
"AT-55",
"AT-55 Suave 5%",
"AT-83 Basic M",
"AT-83 Basic M Suave 2,5%",
"AT-83 IAM M",
"BR-EMSmt-v.2021 M",
"BR-EMSmt-v.2021 M Agrav 24%",
"GKM-95",
"GR-95 M",
"Prudential-50 Suav. 16%",
"Prudential-50 Suav. 17%",
"Prudential-50 Suav. 18%",
"Prudential-50 Suav. 19%",
"Prudential-50 Suav. 19,5%",
"Prudential-50 Suav. 20%",
"RP-2000 M",
"UP - 94 M",
"2012 AIM table M",
"CL5",
"CL6",
"BR-EMSmt 2015 M",
"BR-EMSmt 2015 M Agrav 20%",
"BR-EMSmt 2015 M Agrav 25%",
"BREMSsb 2015 M",
"TR 2025",
"Petros",
"M-95 H Suave 6%"
]

lista_tabua_exsup_fem = [
"IBGE 2024 F Extrap",
"AT-2000 (Suav 10%) F",
"AT-2000 F",
"AT-83 Basic F",
"AT-83 IAM F",
"BR-EMSmt-v.2021 F",
"BR-EMSmt-v.2021 F Agrav. 21,5%",
"BR-EMSsb-v.2021 F",
"GAM-71 F",
"GAM-71 F Suav 5%",
"GAM-71 F Suav 7,5%",
"GAM-71 F Suav 10%",
"GKF-95",
"GR-95 F",
"IBGE 2020 Extrap. F",
"RP-2000 F",
"UP - 94 F",
"2012 AIM table F",
"CL5",
"CL6",
"IBGE 2019 Extrap. F",
"BREMSmt 2015 F",
"BREMSsb 2015 F",
"Petros Suavizada 13%",
"Petros Suavizada 15%",
"Petros Suavizada 17%",
"M-95 M Suav. 7%"
]

lista_tabua_pminf_fem = [
    "BR-EMSmt-v.2021 F Agrav. 21,5%",
    "GAM-71 F",
    "GAM-71 F Suav 5%",
    "Petros Suavizada 13%"
]

# %% [markdown]
# ### Masculino

# %%
tabua_referencia = bib.Calculos.calcular_tabua(df_tabuas_masc["IBGE 2024 Extrap M"])

faixas_ativos = [(18,25), (26,30), (31,35), (36,40), (41,45), (46,50), (51,55), (56,60), (61,64)]
faixas_aposentados = [(65,70), (71,75), (76,80), (81,85), (86,90), (91,95), (96, 100)]

lista_proporcoes = list(proporcoes_masc_jovem.values())
proporcoes_ativos     = lista_proporcoes[:9]   # faixas 18–64
proporcoes_aposentados = lista_proporcoes[9:]  # faixas 65–100

# Referência
lx_ativos_referencia = [
    tabua_referencia.loc[(tabua_referencia['Idade'] >= i) & (tabua_referencia['Idade'] <= f), 'lx'].sum()
    for i, f in faixas_ativos
]
lx_aposentados_referencia = [
    tabua_referencia.loc[(tabua_referencia['Idade'] >= i) & (tabua_referencia['Idade'] <= f), 'lx'].sum()
    for i, f in faixas_aposentados
]

sp_ativo_referencia      = sum(v * p for v, p in zip(lx_ativos_referencia,      proporcoes_ativos))
sp_aposentados_referencia = sum(v * p for v, p in zip(lx_aposentados_referencia, proporcoes_aposentados))

lista_resultados = []

for tabua in tabuas_masculinas:
    if tabua != "IBGE 2024 Extrap M":
        tabua_comparativa = bib.Calculos.calcular_tabua(df_tabuas_masc[tabua])

        lx_ativos_comparativa = [
            tabua_comparativa.loc[(tabua_comparativa['Idade'] >= i) & (tabua_comparativa['Idade'] <= f), 'lx'].sum()
            for i, f in faixas_ativos
        ]
        lx_aposentados_comparativa = [
            tabua_comparativa.loc[(tabua_comparativa['Idade'] >= i) & (tabua_comparativa['Idade'] <= f), 'lx'].sum()
            for i, f in faixas_aposentados
        ]

        sp_ativo_comparativa      = sum(v * p for v, p in zip(lx_ativos_comparativa,      proporcoes_ativos))
        sp_aposentados_comparativa = sum(v * p for v, p in zip(lx_aposentados_comparativa, proporcoes_aposentados))

        razao_ativo       = ((sp_ativo_comparativa      / sp_ativo_referencia)      - 1) * 100
        razao_aposentados = ((sp_aposentados_comparativa / sp_aposentados_referencia) - 1) * 100

        lista_resultados.append({
            "tabua": tabua,
            "razao ativo": razao_ativo,
            "razao aposentado": razao_aposentados,
            "ex sup": tabua in lista_tabua_exsup_masc,
            "RM<":   tabua in lista_tabua_pminf_masc
        })

df_ind = pd.DataFrame(lista_resultados)
df_ind[df_ind["RM<"] == True]
# Out:
#                       tabua  razao ativo  razao aposentado  ex sup   RM<
# 38  Prudential-50 Suav. 16%     3.841079          5.097851    True  True

# %% [markdown]
# ### Feminina

# %%
tabua_referencia = bib.Calculos.calcular_tabua(df_tabuas_fem["IBGE 2024 F Extrap"])

faixas_ativos = [(18,25), (26,30), (31,35), (36,40), (41,45), (46,50), (51,55), (56,60), (61,64)]
faixas_aposentados = [(65,70), (71,75), (76,80), (81,85), (86,90), (91,95), (96, 100)]

lista_proporcoes = list(proporcoes_fem_jovem.values())
proporcoes_ativos     = lista_proporcoes[:9]   # faixas 18–64
proporcoes_aposentados = lista_proporcoes[9:]  # faixas 65–100

# Referência
lx_ativos_referencia = [
    tabua_referencia.loc[(tabua_referencia['Idade'] >= i) & (tabua_referencia['Idade'] <= f), 'lx'].sum()
    for i, f in faixas_ativos
]
lx_aposentados_referencia = [
    tabua_referencia.loc[(tabua_referencia['Idade'] >= i) & (tabua_referencia['Idade'] <= f), 'lx'].sum()
    for i, f in faixas_aposentados
]

sp_ativo_referencia      = sum(v * p for v, p in zip(lx_ativos_referencia,      proporcoes_ativos))
sp_aposentados_referencia = sum(v * p for v, p in zip(lx_aposentados_referencia, proporcoes_aposentados))

lista_resultados = []

for tabua in tabuas_femininas:
    if tabua != "IBGE 2024 F Extrap":
        tabua_comparativa = bib.Calculos.calcular_tabua(df_tabuas_fem[tabua])

        lx_ativos_comparativa = [
            tabua_comparativa.loc[(tabua_comparativa['Idade'] >= i) & (tabua_comparativa['Idade'] <= f), 'lx'].sum()
            for i, f in faixas_ativos
        ]
        lx_aposentados_comparativa = [
            tabua_comparativa.loc[(tabua_comparativa['Idade'] >= i) & (tabua_comparativa['Idade'] <= f), 'lx'].sum()
            for i, f in faixas_aposentados
        ]

        sp_ativo_comparativa      = sum(v * p for v, p in zip(lx_ativos_comparativa,      proporcoes_ativos))
        sp_aposentados_comparativa = sum(v * p for v, p in zip(lx_aposentados_comparativa, proporcoes_aposentados))

        razao_ativo       = ((sp_ativo_comparativa      / sp_ativo_referencia)      - 1) * 100
        razao_aposentados = ((sp_aposentados_comparativa / sp_aposentados_referencia) - 1) * 100

        lista_resultados.append({
            "tabua": tabua,
            "razao ativo": razao_ativo,
            "razao aposentado": razao_aposentados,
            "ex sup": tabua in lista_tabua_exsup_fem,
            "RM<":   tabua in lista_tabua_pminf_fem
        })

df_ind = pd.DataFrame(lista_resultados)
df_ind[df_ind["ex sup"] == True]
# Out:
#                              tabua  razao ativo  razao aposentado  ex sup  \
# 1             AT-2000 (Suav 10%) F     1.697020         22.094958    True
# 3                        AT-2000 F     1.583886         17.410643    True
# 6                    AT-83 Basic F     2.030125          8.973850    True
# 7                      AT-83 IAM F     1.577638         16.032408    True
# 8                BR-EMSmt-v.2021 F     1.563806         13.206203    True
# 9   BR-EMSmt-v.2021 F Agrav. 21,5%     1.251883          1.032552    True
# 10               BR-EMSsb-v.2021 F     1.847360         27.722707    True
# 12                        GAM-71 F     1.437168          0.611337    True
# 13                GAM-71 F Suav 5%     1.500591          3.114166    True
# 14              GAM-71 F Suav 7,5%     1.532325          4.407965    True
# 15               GAM-71 F Suav 10%     1.564073          5.731382    True
# 17                          GKF-95     1.895244          9.046053    True
# ...

# %% [markdown]
# ### Graficos

# %%
idade = df_tabuas_masc["Idade"]
ibge = bib.Calculos.calcular_tabua(df_tabuas_masc["IBGE 2024 Extrap M"])
at55 = bib.Calculos.calcular_tabua(df_tabuas_masc["AT-55"])
brems = bib.Calculos.calcular_tabua(df_tabuas_masc["BR-EMSmt 2015 M Agrav 25%"])

from matplotlib.ticker import FuncFormatter

def formatar_milhar(x, pos):
    return f'{int(x):,}'.replace(',', '.')

fig, ax = plt.subplots(figsize=(10, 8))

ax.plot(idade, ibge["lx"], label='IBGE 2024 Extrap M', color="#000000", linewidth=3)
ax.plot(idade, at55["lx"], label='AT-55', color="#0E85C1", linestyle='--', linewidth=3)
ax.plot(idade, brems["lx"], label="BR-EMSmt 2015 M Agrav 25%", color="#770FAF", linestyle=':', linewidth=3)

ax.axvline(x=65, color="#CB0000", linestyle='-', linewidth=2, label='Idade aposentadoria')

ax.set_xlabel("Idade", fontsize=22)
ax.set_ylabel("Número de sobreviventes $l_x$", fontsize=22)

ax.tick_params(axis='both', labelsize=18)

ax.yaxis.set_major_formatter(FuncFormatter(formatar_milhar))

ax.legend(
    loc='upper right',
    frameon=True,
    framealpha=1,
    facecolor='white',
    title='Tábuas',
    title_fontsize=16,
    fontsize=14
)

plt.savefig("curva_lx_masc.pdf")

plt.show()

# %%
idade = df_tabuas_fem["Idade"]
ibge = bib.Calculos.calcular_tabua(df_tabuas_fem["IBGE 2024 F Extrap"])
gam71 = bib.Calculos.calcular_tabua(df_tabuas_fem["GAM-71 F"])
at83 = bib.Calculos.calcular_tabua(df_tabuas_fem["GKF-95"])

from matplotlib.ticker import FuncFormatter

def formatar_milhar(x, pos):
    return f'{int(x):,}'.replace(',', '.')

fig, ax = plt.subplots(figsize=(10, 8))

ax.plot(idade, ibge["lx"], label='IBGE 2024 F Extrap', color="#000000", linewidth=3)
ax.plot(idade, gam71["lx"], label='GAM-71 F', color="#0E85C1", linestyle='--', linewidth=3)
ax.plot(idade, at83["lx"], label='GKF-95', color="#770FAF", linestyle=':', linewidth=3)

ax.axvline(x=62, color="#CB0000", linestyle='-', linewidth=2, label='Idade aposentadoria')

ax.set_xlabel("Idade", fontsize=22)
ax.set_ylabel("Número de sobreviventes $l_x$", fontsize=22)

ax.tick_params(axis='both', labelsize=18)

ax.yaxis.set_major_formatter(FuncFormatter(formatar_milhar))

ax.legend(
    loc='upper right',
    frameon=True,
    framealpha=1,
    facecolor='white',
    title='Tábuas',
    title_fontsize=16,
    fontsize=14
)

plt.savefig("curva_lx_fem.pdf")
plt.show()

# %% [markdown]
# ## Equilibrada

# %% [markdown]
# ### Tabuas

# %%
lista_tabua_pminf_masc = [
    "IBGE 2019 Extrap. A Agrav 18,3%",
    "AT-2000 M Agrav. 33%",
    "AT-55 Suave 5%",
    "AT-83 Basic M Suave 2,5%",
    "BR-EMSmt-v.2021 M Agrav 30%",
    "Prudential-50 Suav. 16%",
    "M-95 H Suave 6%",
    "IBGE 2021 Extrap M Suav 1%",
    "BR-EMSmt-v.2021 M Agrav 24%"
]

lista_tabua_exsup_masc = [
    "IBGE 2021 Extrap M Suav 1%",
    "IBGE 2019 Extrap. A",
    "IBGE 2019 Extrap. A Agrav 18,3%",
    "IBGE 2018 Extrap. A",
    "AT-2000 (Suav 10%) M",
    "AT-2000 M",
    "AT-2000 M Agrav. 33%",
    "AT-55 Suave 5%",
    "AT-83 Basic M Suave 2,5%",
    "AT-83 IAM M",
    "BR-EMSmt-v.2021 M",
    "BR-EMSmt-v.2021 M Agrav 24%",
    "GR-95 M",
    "Prudential-50 Suav. 16%",
    "Prudential-50 Suav. 17%",
    "Prudential-50 Suav. 18%",
    "Prudential-50 Suav. 19%",
    "Prudential-50 Suav. 19,5%",
    "Prudential-50 Suav. 20%",
    "RP-2000 M",
    "UP - 94 M",
    "2012 AIM table M",
    "CL5",
    "CL6",
    "BR-EMSmt 2015 M",
    "BR-EMSmt 2015 M Agrav 20%",
    "BR-EMSmt 2015 M Agrav 25%",
    "BREMSsb 2015 M",
    "TR 2025",
    "Petros",
    "M-95 H Suave 6%"
]

lista_tabua_exsup_fem = [
    "AT-2000 (Suav 10%) F",
    "AT-2000 F",
    "AT-83 Basic F",
    "AT-83 IAM F",
    "BR-EMSmt-v.2021 F",
    "BR-EMSmt-v.2021 F Agrav. 21,5%",
    "BR-EMSsb-v.2021 F",
    "GAM-71 F Suav 5%",
    "GAM-71 F Suav 7,5%",
    "GAM-71 F Suav 10%",
    "GKF-95",
    "GR-95 F",
    "IBGE 2020 Extrap. F",
    "RP-2000 F",
    "UP - 94 F",
    "2012 AIM table F",
    "CL5",
    "CL6",
    "IBGE 2019 Extrap. Ambos Suave 19%",
    "IBGE 2019 Extrap. F",
    "BREMSmt 2015 F",
    "BREMSsb 2015 F",
    "Petros Suavizada 15%",
    "Petros Suavizada 17%",
    "M-95 M Suav. 7%"
]

lista_tabua_pminf_fem = [
    "BR-EMSmt-v.2021 F Agrav. 21,5%",
    "IBGE 2019 Extrap. A Suave 19%",
    "IBGE 2019 Extrap. F",
    "Petros Suavizada 15%",
    "IBGE 2019 Extrap. Ambos Suave 19%",
    "GAM-71 F Suav 5%",
    "IBGE 2020 Extrap. F"
]

# %% [markdown]
# ### Masculino

# %%
tabua_referencia = bib.Calculos.calcular_tabua(df_tabuas_masc["IBGE 2024 Extrap M"])

faixas_ativos = [(18,25), (26,30), (31,35), (36,40), (41,45), (46,50), (51,55), (56,60), (61,64)]
faixas_aposentados = [(65,70), (71,75), (76,80), (81,85), (86,90), (91,95), (96, 100)]

lista_proporcoes = list(proporcoes_masc_equilibrada.values())
proporcoes_ativos     = lista_proporcoes[:9]   # faixas 18–64
proporcoes_aposentados = lista_proporcoes[9:]  # faixas 65–100

# Referência
lx_ativos_referencia = [
    tabua_referencia.loc[(tabua_referencia['Idade'] >= i) & (tabua_referencia['Idade'] <= f), 'lx'].sum()
    for i, f in faixas_ativos
]
lx_aposentados_referencia = [
    tabua_referencia.loc[(tabua_referencia['Idade'] >= i) & (tabua_referencia['Idade'] <= f), 'lx'].sum()
    for i, f in faixas_aposentados
]

sp_ativo_referencia      = sum(v * p for v, p in zip(lx_ativos_referencia,      proporcoes_ativos))
sp_aposentados_referencia = sum(v * p for v, p in zip(lx_aposentados_referencia, proporcoes_aposentados))

lista_resultados = []

for tabua in tabuas_masculinas:
    if tabua != "IBGE 2024 Extrap M":
        tabua_comparativa = bib.Calculos.calcular_tabua(df_tabuas_masc[tabua])

        lx_ativos_comparativa = [
            tabua_comparativa.loc[(tabua_comparativa['Idade'] >= i) & (tabua_comparativa['Idade'] <= f), 'lx'].sum()
            for i, f in faixas_ativos
        ]
        lx_aposentados_comparativa = [
            tabua_comparativa.loc[(tabua_comparativa['Idade'] >= i) & (tabua_comparativa['Idade'] <= f), 'lx'].sum()
            for i, f in faixas_aposentados
        ]

        sp_ativo_comparativa      = sum(v * p for v, p in zip(lx_ativos_comparativa,      proporcoes_ativos))
        sp_aposentados_comparativa = sum(v * p for v, p in zip(lx_aposentados_comparativa, proporcoes_aposentados))

        razao_ativo       = ((sp_ativo_comparativa      / sp_ativo_referencia)      - 1) * 100
        razao_aposentados = ((sp_aposentados_comparativa / sp_aposentados_referencia) - 1) * 100

        lista_resultados.append({
            "tabua": tabua,
            "razao ativo": razao_ativo,
            "razao aposentado": razao_aposentados,
            "ex sup": tabua in lista_tabua_exsup_masc,
            "RM<":   tabua in lista_tabua_pminf_masc
        })

df_ind = pd.DataFrame(lista_resultados)
df_ind[df_ind["RM<"] == True]
# Out:
#                               tabua  razao ativo  razao aposentado  ex sup  \
# 7        IBGE 2021 Extrap M Suav 1%     0.186000         -0.283876    True
# 11  IBGE 2019 Extrap. A Agrav 18,3%     0.869702          0.558857    True
# 18             AT-2000 M Agrav. 33%     4.056781          4.248942    True
# 22                   AT-55 Suave 5%     5.519302          4.485135    True
# 24         AT-83 Basic M Suave 2,5%     6.203862          6.316520    True
# 27      BR-EMSmt-v.2021 M Agrav 24%     4.091357          4.154190    True
# 35          Prudential-50 Suav. 16%     5.909954          5.022042    True
# 59                  M-95 H Suave 6%     1.874157          1.281413    True
#
#      RM<
# 7   True
# 11  True
# 18  True
# 22  True
# 24  True
# 27  True
# 35  True
# 59  True

# %% [markdown]
# ### Feminino

# %%
tabua_referencia = bib.Calculos.calcular_tabua(df_tabuas_fem["IBGE 2024 F Extrap"])

faixas_ativos = [(18,25), (26,30), (31,35), (36,40), (41,45), (46,50), (51,55), (56,60), (61,64)]
faixas_aposentados = [(65,70), (71,75), (76,80), (81,85), (86,90), (91,95), (96, 100)]

lista_proporcoes = list(proporcoes_fem_equilibrada.values())
proporcoes_ativos     = lista_proporcoes[:9]   # faixas 18–64
proporcoes_aposentados = lista_proporcoes[9:]  # faixas 65–100

# Referência
lx_ativos_referencia = [
    tabua_referencia.loc[(tabua_referencia['Idade'] >= i) & (tabua_referencia['Idade'] <= f), 'lx'].sum()
    for i, f in faixas_ativos
]
lx_aposentados_referencia = [
    tabua_referencia.loc[(tabua_referencia['Idade'] >= i) & (tabua_referencia['Idade'] <= f), 'lx'].sum()
    for i, f in faixas_aposentados
]

sp_ativo_referencia      = sum(v * p for v, p in zip(lx_ativos_referencia,      proporcoes_ativos))
sp_aposentados_referencia = sum(v * p for v, p in zip(lx_aposentados_referencia, proporcoes_aposentados))

lista_resultados = []

for tabua in tabuas_femininas:
    if tabua != "IBGE 2024 F Extrap":
        tabua_comparativa = bib.Calculos.calcular_tabua(df_tabuas_fem[tabua])

        lx_ativos_comparativa = [
            tabua_comparativa.loc[(tabua_comparativa['Idade'] >= i) & (tabua_comparativa['Idade'] <= f), 'lx'].sum()
            for i, f in faixas_ativos
        ]
        lx_aposentados_comparativa = [
            tabua_comparativa.loc[(tabua_comparativa['Idade'] >= i) & (tabua_comparativa['Idade'] <= f), 'lx'].sum()
            for i, f in faixas_aposentados
        ]

        sp_ativo_comparativa      = sum(v * p for v, p in zip(lx_ativos_comparativa,      proporcoes_ativos))
        sp_aposentados_comparativa = sum(v * p for v, p in zip(lx_aposentados_comparativa, proporcoes_aposentados))

        razao_ativo       = ((sp_ativo_comparativa      / sp_ativo_referencia)      - 1) * 100
        razao_aposentados = ((sp_aposentados_comparativa / sp_aposentados_referencia) - 1) * 100

        lista_resultados.append({
            "tabua": tabua,
            "razao ativo": razao_ativo,
            "razao aposentado": razao_aposentados,
            "ex sup": tabua in lista_tabua_exsup_fem,
            "RM<":   tabua in lista_tabua_pminf_fem
        })

df_ind = pd.DataFrame(lista_resultados)
df_ind[df_ind["RM<"] == True]
# Out:
#                                 tabua  razao ativo  razao aposentado  ex sup  \
# 9      BR-EMSmt-v.2021 F Agrav. 21,5%     1.489978          0.808679    True
# 13                   GAM-71 F Suav 5%     2.102488          4.235726    True
# 19                IBGE 2020 Extrap. F     0.217609         -0.494069    True
# 33  IBGE 2019 Extrap. Ambos Suave 19%    -1.066995         -3.396284    True
# 34                IBGE 2019 Extrap. F     0.123943         -1.120906    True
# 47               Petros Suavizada 15%     2.685469          2.594684    True
#
#      RM<
# 9   True
# 13  True
# 19  True
# 33  True
# 34  True
# 47  True

# %% [markdown]
# ## Idosa

# %% [markdown]
# ### Tabuas

# %%
lista_tabua_pminf_masc = ["TR 2025", "Prudential-50 Suav. 19%", "RP-2000 M", "UP - 94 M", "Petros"]

lista_tabua_exsup_masc = [
    "IBGE 2021 Extrap M",
    "IBGE 2021 Extrap M Suav 1%",
    "IBGE 2020 Extrap. M",
    "IBGE 2019 Extrap. A",
    "IBGE 2018 Extrap. A",
    "IBGE 2018 Extrap. M Suave 2,5%",
    "AT-2000 (Suav 10%) M",
    "AT-2000 M",
    "AT-83 IAM M",
    "BR-EMSmt-v.2021 M",
    "GR-95 M",
    "Prudential-50 Suav. 19%",
    "Prudential-50 Suav. 19,5%",
    "Prudential-50 Suav. 20%",
    "RP-2000 M",
    "UP - 94 M",
    "2012 AIM table M",
    "CL5",
    "CL6",
    "BR-EMSmt 2015 M",
    "BR-EMSmt 2015 M Agrav 20%",
    "BR-EMSmt 2015 M Agrav 25%",
    "BREMSsb 2015 M",
    "TR 2025",
    "Petros"
]

lista_tabua_exsup_fem = [
    "AT-2000 (Suav 10%) F",
    "AT-2000 F",
    "AT-83 Basic F",
    "AT-83 IAM F",
    "BR-EMSmt-v.2021 F",
    "BR-EMSsb-v.2021 F",
    "GAM-71 F Suav 10%",
    "GKF-95",
    "GR-95 F",
    "IBGE 2020 Extrap. F",
    "RP-2000 F",
    "UP - 94 F",
    "2012 AIM table F",
    "CL5",
    "CL6",
    "IBGE 2019 Extrap. Ambos Suave 19%",
    "IBGE 2019 Extrap. F",
    "IBGE 2018 Extrap. F",
    "BREMSmt 2015 F",
    "BREMSsb 2015 F",
    "M-95 M Suav. 7%"
]

lista_tabua_pminf_fem = [
    "M-95 M Suav. 7%", "AT-83 Basic F", "RP-2000 F", "CL5"
]

# %% [markdown]
# ### Masculino

# %%
tabua_referencia = bib.Calculos.calcular_tabua(df_tabuas_masc["IBGE 2024 Extrap M"])

faixas_ativos = [(18,25), (26,30), (31,35), (36,40), (41,45), (46,50), (51,55), (56,60), (61,64)]
faixas_aposentados = [(65,70), (71,75), (76,80), (81,85), (86,90), (91,95), (96, 100)]

lista_proporcoes = list(proporcoes_masc_idosa.values())
proporcoes_ativos     = lista_proporcoes[:9]   # faixas 18–64
proporcoes_aposentados = lista_proporcoes[9:]  # faixas 65–100

# Referência
lx_ativos_referencia = [
    tabua_referencia.loc[(tabua_referencia['Idade'] >= i) & (tabua_referencia['Idade'] <= f), 'lx'].sum()
    for i, f in faixas_ativos
]
lx_aposentados_referencia = [
    tabua_referencia.loc[(tabua_referencia['Idade'] >= i) & (tabua_referencia['Idade'] <= f), 'lx'].sum()
    for i, f in faixas_aposentados
]

sp_ativo_referencia      = sum(v * p for v, p in zip(lx_ativos_referencia,      proporcoes_ativos))
sp_aposentados_referencia = sum(v * p for v, p in zip(lx_aposentados_referencia, proporcoes_aposentados))

lista_resultados = []

for tabua in tabuas_masculinas:
    if tabua != "IBGE 2024 Extrap M":
        tabua_comparativa = bib.Calculos.calcular_tabua(df_tabuas_masc[tabua])

        lx_ativos_comparativa = [
            tabua_comparativa.loc[(tabua_comparativa['Idade'] >= i) & (tabua_comparativa['Idade'] <= f), 'lx'].sum()
            for i, f in faixas_ativos
        ]
        lx_aposentados_comparativa = [
            tabua_comparativa.loc[(tabua_comparativa['Idade'] >= i) & (tabua_comparativa['Idade'] <= f), 'lx'].sum()
            for i, f in faixas_aposentados
        ]

        sp_ativo_comparativa      = sum(v * p for v, p in zip(lx_ativos_comparativa,      proporcoes_ativos))
        sp_aposentados_comparativa = sum(v * p for v, p in zip(lx_aposentados_comparativa, proporcoes_aposentados))

        razao_ativo       = ((sp_ativo_comparativa      / sp_ativo_referencia)      - 1) * 100
        razao_aposentados = ((sp_aposentados_comparativa / sp_aposentados_referencia) - 1) * 100

        lista_resultados.append({
            "tabua": tabua,
            "razao ativo": razao_ativo,
            "razao aposentado": razao_aposentados,
            "ex sup": tabua in lista_tabua_exsup_masc,
            "RM<":   tabua in lista_tabua_pminf_masc
        })

df_ind = pd.DataFrame(lista_resultados)
df_ind[df_ind["RM<"] == True]
# Out:
#                       tabua  razao ativo  razao aposentado  ex sup   RM<
# 38  Prudential-50 Suav. 19%     6.685906          7.600011    True  True
# 42                RP-2000 M     9.626984         21.665175    True  True
# 45                UP - 94 M     8.383971         15.369324    True  True
# 56                  TR 2025     1.906340          4.150053    True  True
# 57                   Petros     9.625220         24.157368    True  True

# %% [markdown]
# ### Feminino

# %%
tabua_referencia = bib.Calculos.calcular_tabua(df_tabuas_fem["IBGE 2024 F Extrap"])

faixas_ativos = [(18,25), (26,30), (31,35), (36,40), (41,45), (46,50), (51,55), (56,60), (61,64)]
faixas_aposentados = [(65,70), (71,75), (76,80), (81,85), (86,90), (91,95), (96, 100)]

lista_proporcoes = list(proporcoes_fem_idosa.values())
proporcoes_ativos     = lista_proporcoes[:9]   # faixas 18–64
proporcoes_aposentados = lista_proporcoes[9:]  # faixas 65–100

# Referência
lx_ativos_referencia = [
    tabua_referencia.loc[(tabua_referencia['Idade'] >= i) & (tabua_referencia['Idade'] <= f), 'lx'].sum()
    for i, f in faixas_ativos
]
lx_aposentados_referencia = [
    tabua_referencia.loc[(tabua_referencia['Idade'] >= i) & (tabua_referencia['Idade'] <= f), 'lx'].sum()
    for i, f in faixas_aposentados
]

sp_ativo_referencia      = sum(v * p for v, p in zip(lx_ativos_referencia,      proporcoes_ativos))
sp_aposentados_referencia = sum(v * p for v, p in zip(lx_aposentados_referencia, proporcoes_aposentados))

lista_resultados = []

for tabua in tabuas_femininas:
    if tabua != "IBGE 2024 F Extrap":
        tabua_comparativa = bib.Calculos.calcular_tabua(df_tabuas_fem[tabua])

        lx_ativos_comparativa = [
            tabua_comparativa.loc[(tabua_comparativa['Idade'] >= i) & (tabua_comparativa['Idade'] <= f), 'lx'].sum()
            for i, f in faixas_ativos
        ]
        lx_aposentados_comparativa = [
            tabua_comparativa.loc[(tabua_comparativa['Idade'] >= i) & (tabua_comparativa['Idade'] <= f), 'lx'].sum()
            for i, f in faixas_aposentados
        ]

        sp_ativo_comparativa      = sum(v * p for v, p in zip(lx_ativos_comparativa,      proporcoes_ativos))
        sp_aposentados_comparativa = sum(v * p for v, p in zip(lx_aposentados_comparativa, proporcoes_aposentados))

        razao_ativo       = ((sp_ativo_comparativa      / sp_ativo_referencia)      - 1) * 100
        razao_aposentados = ((sp_aposentados_comparativa / sp_aposentados_referencia) - 1) * 100

        lista_resultados.append({
            "tabua": tabua,
            "razao ativo": razao_ativo,
            "razao aposentado": razao_aposentados,
            "ex sup": tabua in lista_tabua_exsup_fem,
            "RM<":   tabua in lista_tabua_pminf_fem
        })

df_ind = pd.DataFrame(lista_resultados)
df_ind[df_ind["RM<"] == True]
# Out:
#               tabua  razao ativo  razao aposentado  ex sup   RM<
# 6     AT-83 Basic F     3.817129          8.805033    True  True
# 24        RP-2000 F     3.788188          6.279461    True  True
# 30              CL5     3.247616         10.763421    True  True
# 53  M-95 M Suav. 7%     1.124994          1.719703    True  True

# %% [markdown]
# ## Bimodal

# %% [markdown]
# ### Tabuas

# %%
lista_tabua_pminf_masc = [
    "IBGE 2019 Extrap. A Agrav 18,3%",
    "Prudential-50 Suav. 18%",
    "RP-2000 M",
    "UP - 94 M",
    "Petros"
]

lista_tabua_exsup_masc = [
    "IBGE 2021 Extrap M Suav 1%",
    "IBGE 2019 Extrap. A",
    "IBGE 2019 Extrap. A Agrav 18,3%",
    "IBGE 2018 Extrap. A",
    "AT-2000 (Suav 10%) M",
    "AT-2000 M",
    "AT-83 IAM M",
    "BR-EMSmt-v.2021 M",
    "GR-95 M",
    "Prudential-50 Suav. 18%",
    "Prudential-50 Suav. 19%",
    "Prudential-50 Suav. 19,5%",
    "Prudential-50 Suav. 20%",
    "RP-2000 M",
    "UP - 94 M",
    "2012 AIM table M",
    "CL5",
    "CL6",
    "BR-EMSmt 2015 M",
    "BR-EMSmt 2015 M Agrav 20%",
    "BR-EMSmt 2015 M Agrav 25%",
    "BREMSsb 2015 M",
    "TR 2025",
    "Petros"
]

lista_tabua_exsup_fem = [
    "AT-2000 (Suav 10%) F",
    "AT-2000 F",
    "AT-83 Basic F",
    "AT-83 IAM F",
    "BR-EMSmt-v.2021 F",
    "BR-EMSsb-v.2021 F",
    "GAM-71 F Suav 5%",
    "GAM-71 F Suav 7,5%",
    "GAM-71 F Suav 10%",
    "GKF-95",
    "GR-95 F",
    "IBGE 2020 Extrap. F",
    "RP-2000 F",
    "UP - 94 F",
    "2012 AIM table F",
    "CL5",
    "CL6",
    "IBGE 2019 Extrap. Ambos Suave 19%",
    "IBGE 2019 Extrap. F",
    "IBGE 2018 Extrap. F",
    "BREMSmt 2015 F",
    "BREMSsb 2015 F",
    "M-95 M Suav. 7%"
]

lista_tabua_pminf_fem = [
    "GAM-71 F Suav 5%",
    "AT-83 Basic F",
    "RP-2000 F"
]

# %% [markdown]
# ### Masculino

# %%
tabua_referencia = bib.Calculos.calcular_tabua(df_tabuas_masc["IBGE 2024 Extrap M"])

faixas_ativos = [(18,25), (26,30), (31,35), (36,40), (41,45), (46,50), (51,55), (56,60), (61,64)]
faixas_aposentados = [(65,70), (71,75), (76,80), (81,85), (86,90), (91,95), (96, 100)]

lista_proporcoes = list(proporcoes_masc_bimodal.values())
proporcoes_ativos     = lista_proporcoes[:9]   # faixas 18–64
proporcoes_aposentados = lista_proporcoes[9:]  # faixas 65–100

# Referência
lx_ativos_referencia = [
    tabua_referencia.loc[(tabua_referencia['Idade'] >= i) & (tabua_referencia['Idade'] <= f), 'lx'].sum()
    for i, f in faixas_ativos
]
lx_aposentados_referencia = [
    tabua_referencia.loc[(tabua_referencia['Idade'] >= i) & (tabua_referencia['Idade'] <= f), 'lx'].sum()
    for i, f in faixas_aposentados
]

sp_ativo_referencia      = sum(v * p for v, p in zip(lx_ativos_referencia,      proporcoes_ativos))
sp_aposentados_referencia = sum(v * p for v, p in zip(lx_aposentados_referencia, proporcoes_aposentados))

lista_resultados = []

for tabua in tabuas_masculinas:
    if tabua != "IBGE 2024 Extrap M":
        tabua_comparativa = bib.Calculos.calcular_tabua(df_tabuas_masc[tabua])

        lx_ativos_comparativa = [
            tabua_comparativa.loc[(tabua_comparativa['Idade'] >= i) & (tabua_comparativa['Idade'] <= f), 'lx'].sum()
            for i, f in faixas_ativos
        ]
        lx_aposentados_comparativa = [
            tabua_comparativa.loc[(tabua_comparativa['Idade'] >= i) & (tabua_comparativa['Idade'] <= f), 'lx'].sum()
            for i, f in faixas_aposentados
        ]

        sp_ativo_comparativa      = sum(v * p for v, p in zip(lx_ativos_comparativa,      proporcoes_ativos))
        sp_aposentados_comparativa = sum(v * p for v, p in zip(lx_aposentados_comparativa, proporcoes_aposentados))

        razao_ativo       = ((sp_ativo_comparativa      / sp_ativo_referencia)      - 1) * 100
        razao_aposentados = ((sp_aposentados_comparativa / sp_aposentados_referencia) - 1) * 100

        lista_resultados.append({
            "tabua": tabua,
            "razao ativo": razao_ativo,
            "razao aposentado": razao_aposentados,
            "ex sup": tabua in lista_tabua_exsup_masc,
            "RM<":   tabua in lista_tabua_pminf_masc
        })

df_ind = pd.DataFrame(lista_resultados)
df_ind[df_ind["RM<"] == True]
# Out:
#                               tabua  razao ativo  razao aposentado  ex sup  \
# 11  IBGE 2019 Extrap. A Agrav 18,3%     0.527878          0.981576    True
# 37          Prudential-50 Suav. 18%     4.937414          7.162747    True
# 42                        RP-2000 M     6.535272         21.177018    True
# 45                        UP - 94 M     5.742333         15.595972    True
# 57                           Petros     6.767634         21.426439    True
#
#      RM<
# 11  True
# 37  True
# 42  True
# 45  True
# 57  True

# %% [markdown]
# ### Feminino

# %%
tabua_referencia = bib.Calculos.calcular_tabua(df_tabuas_fem["IBGE 2024 F Extrap"])

faixas_ativos = [(18,25), (26,30), (31,35), (36,40), (41,45), (46,50), (51,55), (56,60), (61,64)]
faixas_aposentados = [(65,70), (71,75), (76,80), (81,85), (86,90), (91,95), (96, 100)]

lista_proporcoes = list(proporcoes_fem_bimodal.values())
proporcoes_ativos     = lista_proporcoes[:9]   # faixas 18–64
proporcoes_aposentados = lista_proporcoes[9:]  # faixas 65–100

# Referência
lx_ativos_referencia = [
    tabua_referencia.loc[(tabua_referencia['Idade'] >= i) & (tabua_referencia['Idade'] <= f), 'lx'].sum()
    for i, f in faixas_ativos
]
lx_aposentados_referencia = [
    tabua_referencia.loc[(tabua_referencia['Idade'] >= i) & (tabua_referencia['Idade'] <= f), 'lx'].sum()
    for i, f in faixas_aposentados
]

sp_ativo_referencia      = sum(v * p for v, p in zip(lx_ativos_referencia,      proporcoes_ativos))
sp_aposentados_referencia = sum(v * p for v, p in zip(lx_aposentados_referencia, proporcoes_aposentados))

lista_resultados = []

for tabua in tabuas_femininas:
    if tabua != "IBGE 2024 F Extrap":
        tabua_comparativa = bib.Calculos.calcular_tabua(df_tabuas_fem[tabua])

        lx_ativos_comparativa = [
            tabua_comparativa.loc[(tabua_comparativa['Idade'] >= i) & (tabua_comparativa['Idade'] <= f), 'lx'].sum()
            for i, f in faixas_ativos
        ]
        lx_aposentados_comparativa = [
            tabua_comparativa.loc[(tabua_comparativa['Idade'] >= i) & (tabua_comparativa['Idade'] <= f), 'lx'].sum()
            for i, f in faixas_aposentados
        ]

        sp_ativo_comparativa      = sum(v * p for v, p in zip(lx_ativos_comparativa,      proporcoes_ativos))
        sp_aposentados_comparativa = sum(v * p for v, p in zip(lx_aposentados_comparativa, proporcoes_aposentados))

        razao_ativo       = ((sp_ativo_comparativa      / sp_ativo_referencia)      - 1) * 100
        razao_aposentados = ((sp_aposentados_comparativa / sp_aposentados_referencia) - 1) * 100

        lista_resultados.append({
            "tabua": tabua,
            "razao ativo": razao_ativo,
            "razao aposentado": razao_aposentados,
            "ex sup": tabua in lista_tabua_exsup_fem,
            "RM<":   tabua in lista_tabua_pminf_fem
        })

df_ind = pd.DataFrame(lista_resultados)
df_ind[df_ind["RM<"] == True]
# Out:
#                tabua  razao ativo  razao aposentado  ex sup   RM<
# 6      AT-83 Basic F     3.077419          8.430118    True  True
# 13  GAM-71 F Suav 5%     2.357228          4.560067    True  True
# 24         RP-2000 F     2.999620          6.373433    True  True
